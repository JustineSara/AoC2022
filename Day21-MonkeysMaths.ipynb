# %%
import re

# %%
test_input = """root: pppw + sjmn
dbpl: 5
cczh: sllz + lgvd
zczc: 2
ptdq: humn - dvpt
dvpt: 3
lfqf: 4
humn: 5
ljgn: 2
sjmn: drzm * dbpl
sllz: 4
pppw: cczh / lfqf
lgvd: ljgn * ptdq
drzm: hmdt - zczc
hmdt: 32"""

# %%
import requests

URL = "https://adventofcode.com/{year}/day/{day}/input"
url = URL.format(year='2022', day=21)
cookies = {"session":"53616c7465645f5fd345d8c12076a357c8d31b2c0c4ad1c152eefbd5c1cf09e0c8d6d7f657fc558887d443d2d07fbc90728ada9b6a91afcecb9926ffb4981a93"}
req = requests.get(url, cookies=cookies)

if req.status_code != 200:
    print("Error. Got status:", req.status_code)
    print(req.text)
    exit(3)
else:
    my_input = req.text

# %%
# Out:
# 'mvnb: mhgv * zvcm\nnrwg: pqnb + wznq\nmcbv: 1\nvwnl: 15\nggdz: bgvn + mwjn\nnnmj: snhj * fpmt\nzmzd: ttjq * zrhr\ntdpj: nvdr * mlmj\nmdps: jfrh * spnj\nwmwm: fdcg * pmbd\nqrcq: vrpq + bwpv\nsgzv: 2\nzhrt: 5\nmzwm: lzmq + ldzw\nbwhp: 2\nclfd: 4\nrmwq: 11\npqtc: srtc * vjhc\ncqrh: bnph * jzrj\nmbjq: 5\ntqdl: rfll + dbhj\nlsbb: 11\nfcld: cgjq * qmbc\nmqvz: 6\ndghz: 8\nqncq: 5\nnsql: csns - lrfq\nqzfg: 2\nwsqv: 1\nvjph: bwwn * qjmh\ndsjq: wnls * pdqm\ntmhv: frmn * cmdn\npqnf: ljhb * zzdg\nrhmw: bjcm * mqzs\ntgtv: psgh * ndbj\ncqgs: 4\nvthp: 5\nzcfd: ffdn - gwgf\ntsrp: nlbv * ptbr\ncldw: 2\nnmlz: 2\npjhm: mhvf * cdms\nnmln: dhwj * gfnb\nldzw: bbls + qwhm\nfljd: rbvm * fprb\ngwhp: jvbm + rrwh\npjmc: mtrd + wljp\ngnph: crdg + zvqd\nbccm: nctz + fvcp\ngwjj: fclp * fplf\nqsth: wshg * lspl\nttcl: gpmj * wftl\nggrv: 3\nbvqd: mdds * jrpz\nnglg: 2\nddpq: 10\nwflc: svsd - crbr\nmqzs: 18\nvfnf: 3\nlrdw: gfdg + mbjq\nwflw: glbs + vdsg\njdln: sgln + dsfj\nddlp: 5\nzcmw: mwnc * mjmp\ncqtt: 11\nrswb: 3\nmhzc: mfsc - mgmb\nshlm: tsrp + pfsp\nhbzq: svrr * vzsj\ntvqp: 4\nplsl: 5\ndfnt: 11\nscvz: 3\nnzjp: bhqt * chtc\nwqst: 14\nvfdd: hccl + vwwl\nrzsp: srcq * jrbl\nftgb: wmph * jslc\nqplw: pjdw + pmjb\nfqpq: 3\nbdpv: dldq * gptn\nrlpd: fntc - rlsc\nnrlz: 7\nlmph: 4\nzfzv: 2\nhcpp: 3\nsgjg: 13\nrhth: 11\nmgln: 2\ngpjt: 2\ncgjn: 3\nbglm: 2\nhdvr: hqdc + wvrl\njmdz: tswl + gvcj\nmlmj: wglf - pnwp\nqpdz: dgjl + zrbp\npczj: gwml + gqzf\ngrpd: jdqh - rlqh\nmvbt: qslg * nbfg\nrcsr: 2\nvrsn: 4\nldrz: 9\nzdtn: 3\nzffh: 3\nwmff: gnph + rpmd\nszgr: whnr + vpsw\nvrch: 15\njdzq: jnwq + qznm\nwzdt: tnlq * zcjs\nphfl: mhvh * sqds\nzgzd: mqjh * lgdh\nzhfp: 2\nwqvz: gfnw / tdlb\nzrtm: 2\nlhsz: 2\nvncz: jpcs - mpbh\nnmcn: 5\nfzhd: gfps + dfnt\nvpsw: 3\nwbrz: mssm * bwdn\njrpz: 3\nzzdc: 2\nmdnv: dhzh / stpr\nscrb: twtl * hnts\npqfz: 3\nzlww: 3\nlcbg: hzwm * lhmd\nwggf: jrmf - fhwg\nvtsc: vlsc * qntj\nmtrd: vfbp * pgqs\ngvjs: jzdl + wbsc\nwfqq: 20\ndwpw: tjvc + bzlq\nfpbv: 2\nrcpc: htgv * nrmh\nhlfw: bcch * fdlh\nblgl: 2\nwwps: pttp + vgbb\ndsfj: 3\nbfqz: prrl * htvb\nbcqm: mtfv + pmzz\nbdnm: 2\ndhsh: 2\npgfv: bzvl + zwtw\nnrmh: 2\ngpvs: 5\nqrpw: nssz / dctm\nmhgv: lqsc + htbz\nwqbg: 17\nzlbn: gzmw / dnht\nrzsb: nnnv / zdtn\npsgh: 2\nscct: 5\nnvsr: gllj * dcpl\npmzz: vgmq + cmmb\nqjmh: 5\nllzr: 3\nsfbz: 2\nttcc: mcbf + zfqv\nphwz: jdnw * lbqf\nswbn: hndd * mqlz\nqbfv: 4\nbsgr: 4\ngjvc: sldt + cbtz\nspjp: vqgq * sjqt\nhcdz: 10\nqhgq: 4\ndbdm: 11\nfjdm: 7\nzcpr: 3\nfplf: htfs * hqpl\nzsjz: 2\ncrrp: gtbr + ffdl\nzgzp: 3\nhcfd: 3\ntzqt: jmmc * ddlp\npvnd: bsjw * qwcv\nvfbp: 2\njrmf: 10\nzjfl: cplp * qjzl\nsldt: nccd / rqqc\nvrhr: 5\ngbcj: mzwm / qbtb\npbgg: mvnb + fhvf\nwjjb: 17\nwnlb: 1\nmjhf: tlrc * zshr\nhglg: gmsv - djmf\nwlhn: pbzp * sqsz\nlldd: zsqz + pgqf\ndrmf: 4\nwhfl: 3\nprln: 5\nzwll: blgl + jhjl\nfrqg: hcqt * lmnm\nqhld: 5\nvdql: 4\nsrrm: grcq * lhnc\ngtcf: 4\nlrfq: 4\nnftt: fghr * zmrv\nnbnn: 3\nztsb: 2\nzcjs: 12\nrcvz: dwgv + zffh\njcrg: 4\ncsmf: sdrs + jngq\nsjbs: 2\nhqpv: 2\nmrnr: wtwh * vpwt\nvqgq: 19\nznln: 2\nrhff: mrsq * rdzz\nfplg: 3\nsjsn: lqvb * csqw\nqntj: 2\nhqhq: pmqg + bcqm\npclp: llzr * lhzl\njhrn: sfvv * ztrh\njhvn: hlbn + gvcw\nhthb: 3\ncmmb: trnb - vpst\nqbsb: 2\nmqwl: hfrf + rhmw\ntzwt: 4\nbqvp: 5\nmrsq: 2\ndmzp: nzjp + bflc\ncszc: 5\ntmzb: 9\nqvnb: bvcg * ndzl\ntptp: hqfg * hwns\nsnwq: 7\nfwfp: zttd * lsbb\nrgfr: zdmc * shpg\nqnpc: fmgg * ptwc\nbpfq: pgdg * djnb\nmzhc: 4\npgdg: mjqg * gjnm\nwzzh: stll - lvdf\nprcd: mmzq * lrdw\nchjs: 16\ntfnc: fjdm + rzsb\njdnw: gcln + llpl\nmljm: 12\nvjdj: sjsn * lmtb\nzprg: fwfp + nrzs\npgqf: 1\npgbv: 3\ngzjv: 2\nbpff: dhww * dwlc\nzsnd: 2\nvjhc: lrhg - hzps\nsjrq: 2\nqsdt: pbrm * nbpg\nprrl: 2\nmlnv: 3\ntglc: 1\ngssc: hwrj + wlhn\nrrrv: 4\nzpqf: 6\nslwd: 8\nbnnb: scvz * rcsr\nrmwn: 3\nnvdr: 2\ncwcp: qrpw + hglg\npmjb: 15\npmbd: wcbz - zmsb\nhvvj: dfqf + sssf\ndzhc: dprs * pclp\ndwlc: mcbv + zmzd\nzmcl: 19\nzmnh: mgbq * djzw\nzjjh: 2\nmczw: lzrq * thpr\ngzmw: nbjs - rchf\ncfwb: 3\nfdhh: 4\nswqs: 2\nswrp: ...

# %%
Ops = []
for l in my_input.split("\n") :
    if l == "":
        pass
    
    l= l.replace(":","=")
    try :
        exec(l)
        print(l)
    except :
        Ops.append(l)
# Out:
# mcbv= 1
# vwnl= 15
# sgzv= 2
# zhrt= 5
# bwhp= 2
# clfd= 4
# rmwq= 11
# mbjq= 5
# lsbb= 11
# mqvz= 6
# dghz= 8
# qncq= 5
# qzfg= 2
# wsqv= 1
# cqgs= 4
# vthp= 5
# cldw= 2
# nmlz= 2
# ggrv= 3
# nglg= 2
# ddpq= 10
# mqzs= 18
# vfnf= 3
# ddlp= 5
# cqtt= 11
# rswb= 3
# tvqp= 4
# plsl= 5
# dfnt= 11
# scvz= 3
# wqst= 14
# fqpq= 3
# nrlz= 7
# lmph= 4
# zfzv= 2
# hcpp= 3
# sgjg= 13
# rhth= 11
# mgln= 2
# gpjt= 2
# cgjn= 3
# bglm= 2
# rcsr= 2
# vrsn= 4
# ldrz= 9
# zdtn= 3
# zffh= 3
# vrch= 15
# zhfp= 2
# zrtm= 2
# lhsz= 2
# nmcn= 5
# vpsw= 3
# jrpz= 3
# zzdc= 2
# pqfz= 3
# zlww= 3
# wfqq= 20
# fpbv= 2
# blgl= 2
# dsfj= 3
# bdnm= 2
# dhsh= 2
# nrmh= 2
# gpvs= 5
# wqbg= 17
# psgh= 2
# scct= 5
# qjmh= 5
# llzr= 3
# sfbz= 2
# qbfv= 4
# bsgr= 4
# hcdz= 10
# qhgq= 4
# dbdm= 11
# fjdm= 7
# zcpr= 3
# zsjz= 2
# zgzp= 3
# hcfd= 3
# vfbp= 2
# jrmf= 10
# vrhr= 5
# wjjb= 17
# wnlb= 1
# drmf= 4
# whfl= 3
# prln= 5
# qhld= 5
# vdql= 4
# gtcf= 4
# lrfq= 4
# nbnn= 3
# ztsb= 2
# zcjs= 12
# jcrg= 4
# sjbs= 2
# hqpv= 2
# vqgq= 19
# znln= 2
# fplg= 3
# qntj= 2
# hthb= 3
# qbsb= 2
# tzwt= 4
# bqvp= 5
# mrsq= 2
# cszc= 5
# tmzb= 9
# snwq= 7
# mzhc= 4
# chjs= 16
# mljm= 12
# pgqf= 1
# pgbv= 3
# gzjv= 2
# zsnd= 2
# sjrq= 2
# prrl= 2
# mlnv= 3
# tglc= 1
# rrrv= 4
# zpqf= 6
# slwd= 8
# bnnb= scvz * rcsr
# rmwn= 3
# nvdr= 2
# pmjb= 15
# zmcl= 19
# zjjh= 2
# cfwb= 3
# fdhh= 4
# swqs= 2
# swrp= 5
# bzwg= 3
# zmrv= 4
# jmls= 19
# dqnz= 3
# dvfs= 2
# qgfv= 4
# fvvg= 18
# fmsm= 19
# qlfl= 1
# wsmh= 20
# gwgf= 2
# ltzc= 4
# rrjh= 8
# lgdh= 3
# wshh= 2
# lvbv= 2
# rpjp= 11
# pdtl= 4
# cpmj= 13
# mgzc= 5
# mhvh= 6
# rdsw= 5
# wvqm= 3
# wnzm= 4
# zbcq= 2
# pvfg= 4
# lgcg= 1
# mjrc= 2
# swfb= 5
# pbzp= 3
# smmv= 5
# dndz= 3
# dwms= 4
# qcqm= 4
# dscj= 2
# jnfs= 2
# vtsb= 6
# ztrh= 2
# lhmd= 3
# lslm= 1
# qmcn= 3
# fzzz= 3
# ndnw= 4
# cmqt= 4
# rfqf= 2
# fqvq= 2
# rscb= 2
# jtwb= 1
# lgfc= 5
# qtzt= 17
# pjvb= 8
# hzzt= 2
# rbwp= 11
# vvcf= 4
# vhgj= 1
# fpdd= 10
# fgts= 4
# mmrh= 15
# zwjz= 3
# grdz= 4
# mpwt= 3
# fmjd= 2
# wtrn= 5
# bzsr= 2
# jpcf= 4
# dhbn= 7
# qqlh= 2
# gdfn= 4
# wrqt= 7
# jtln= 5
# jnqt= 6
# pnnc= 2
# jngl= 20
# qmbc= 2
# fqqp= 2
# lsls= 3
# nsqd= 3
# bdjw= 6
# rwwv= 9
# mjmq= 7
# drlc= 2
# nwhm= 8
# bdtj= 2
# jslc= 2
# bsjw= 5
# hzrc= 3
# bwmt= 3
# phhl= 7
# dtfc= 2
# tmlt= 3
# cgrs= 3
# zzrb= 5
# bdct= 17
# rtsv= 2
# rshw= 6
# pdrq= 5
# tgcm= 12
# stjm= 4
# wrpg= 5
# vlfz= 2
# hcqm= 2
# lwwl= 2
# zrzq= 3
# mdsh= 3
# nlbc= 2
# cfnm= 12
# lhrn= 6
# hlzz= 2
# lgvw= 5
# zpth= 2
# crbb= 2
# mrdf= pjvb + zhrt
# vpnq= vlfz * rpjp
# hdrn= 4
# mpbh= wvqm * scct
# scqf= 2
# nbzl= 6
# jdsl= 2
# fdcg= 2
# zwct= 2
# bvcg= 2
# wtgl= 2
# vmdr= 2
# jmwv= 3
# spnj= 2
# mzqf= 4
# pmpv= 1
# bflc= 1
# vzfq= 5
# nvzv= 3
# fhwg= 3
# vzws= 2
# dlpj= 5
# qmrr= qbfv + rbwp
# nsqp= 12
# bwdr= 11
# srmq= vhgj + sgjg
# vpbm= 3
# jrpd= 2
# hpmc= 5
# zwzh= 2
# fwzh= 3
# zmwg= 3
# vjzr= 2
# drbj= 2
# ftns= 4
# zrbp= 6
# bfpl= 5
# nwph= 7
# pcpc= 2
# cmwj= 9
# gtrn= 5
# sbvs= 12
# nmgq= 6
# ndtn= 11
# pwrd= 11
# dvrs= 5
# qjvh= 3
# mmpr= 8
# hnts= 5
# nrhc= 4
# dfpc= 3
# dsqp= 2
# qznm= 2
# mjqg= 5
# hhjc= 2
# wzmd= 3
# gsjl= 3
# wtwh= 18
# jrwd= 2
# ctlf= 13
# nqhp= 15
# jfhf= 7
# dlgv= 3
# mpgr= 2
# mqqn= 11
# sszs= 2
# jzdl= 3
# jmdf= 12
# nnmm= 2
# mhgr= 3
# jcpn= 2
# sqjg= 3
# whdb= 2
# lbcg= 3
# zdcb= 6
# ntcs= 4
# dhww= 6
# sjqv= 2
# lspl= 12
# mvpr= 11
# znvq= 7
# qcrj= 2
# gftc= vjzr * wrpg
# rbvm= 5
# jpnh= 10
# qrtr= 2
# zrtg= 3
# ndzl= 3
# ctjd= 5
# fhfh= 6
# hqpl= jnfs + ldrz
# srtc= 5
# gjnm= 5
# wbht= 2
# sjqt= 5
# fjnb= 2
# clrc= 14
# wnjr= 11
# bdtq= 3
# swhl= 3
# crbr= 1
# vbsv= 7
# stpr= 5
# tlcv= 19
# hqhd= 8
# wcrn= 2
# grfs= 9
# qwvf= 3
# ghcz= 2
# frmn= 7
# cdtd= 1
# vhqn= 11
# jjpc= 16
# hcrb= 3
# lcbm= 6
# pvvz= 17
# prnq= 4
# jbtz= 13
# sbtw= 11
# ccdv= 3
# cqrn= 2
# jlpq= 9
# slhp= 9
# lpcl= qrtr + dlpj
# shpg= 2
# bbdv= 4
# bwwn= hcfd * pgbv
# jfnb= 3
# rlnm= 4
# gwgn= 3
# fsmf= 3
# dbbn= 5
# tfdf= 2
# fmwm= 2
# nswm= 8
# sjfw= 3
# vflc= 16
# dsbm= 3
# vjjf= 7
# jrqb= 9
# wtdg= 5
# bplb= 3
# brmq= 3
# nbpg= 11
# zfpj= 3
# jlzb= 4
# sgln= nbnn * zwjz
# gdwh= 3
# ltgb= 2
# hwns= 3
# jwdm= 2
# qcwb= 17
# humn= 2411
# bvwh= 2
# stmm= 5
# cssw= qcqm * sjfw
# zvrg= 5
# ghzp= 4
# pzpb= 17
# nbfg= 9
# svsj= wtdg * mvpr
# phcr= 2
# glgp= 2
# pjrz= 3
# nflq= 2
# cnbs= 12
# zrhr= 3
# fmgg= 5
# wjdt= nsqp + zlww
# chnh= 2
# ctml= 3
# nrfs= 1
# tvlv= 5
# pcwb= 3
# zfqv= 6
# nhzn= 17
# tnhj= 5
# jmmc= 5
# rqpc= 11
# hnzp= 11
# lqsc= 4
# jgqz= mmrh * hcpp
# lqqp= 11
# gbtd= 5
# cjgw= 2
# tdlb= 2
# jcjn= 3
# njmh= 6
# lbwh= 4
# pcch= 11
# dphq= 14
# vcql= hqpv * stjm
# hqjm= 4
# dlhh= 7
# njqm= 3
# bdvw= 2
# ffhw= 1
# bnph= 3
# ppfh= 3
# gvgg= 3
# vcbt= 3
# vdws= 2
# hhmp= 6
# nmlv= 14
# pfdz= 3
# dhwj= 7
# vpfr= 2
# cqdn= 3
# jcdg= 2
# szvs= 2
# mdfs= 5
# jlnf= 4
# rtdg= 7
# vlzr= 2
# rglz= 13
# qshz= 2
# mtjv= 5
# vpvj= 2
# lbqf= 2
# ghdj= 2
# rmbl= 3
# vcdl= 2
# pmms= 2
# pqjs= 3
# nwbc= 4
# zvhw= jfnb * znln
# hmdf= 2
# qlhd= 6
# zvpt= 2
# zjds= 6
# grmh= 3
# lbdb= 7
# ftdc= 18
# scch= 5
# hsfc= 12
# mcbf= 1
# zzdg= 2
# mwcq= 4
# zntt= 8
# djnb= 2
# vghf= 2
# wrtj= 1
# gvtg= 3
# bbgm= 13
# pmgv= 3
# drbr= 5
# wgsc= 3
# fcch= 3
# lnpn= 2
# lhpw= 8
# mrsm= 5
# gwwr= 4
# hwcr= drmf * zhfp
# zttd= 2
# dlwm= 7
# hjvn= 4
# pftp= 7
# wfpf= 2
# dqrz= 3
# bfbd= 13
# mdds= 9
# ztgt= 5
# ftmb= 8
# vtdv= 9
# swnp= vcql - jtwb
# ggcf= 9
# mszf= 4
# tgbv= 2
# jcvp= 5
# wprn= 8
# zdmc= 13
# tvtd= 3
# lqvb= 11
# gsjf= 4
# jrbl= 3
# wgtb= 3
# vbft= 13
# lhsg= 4
# zsrp= cpmj + lqqp
# fgtb= 15
# fnnl= 4
# whlt= 2
# wdlg= 4
# cttl= 4
# dgjl= 1
# gmnm= 3
# sqsz= 11
# cdms= 2
# tfmc= 3
# tdws= 2
# ttcf= hcrb * ctlf
# jqhm= 2
# htzv= 5
# qcdp= 3
# pmjv= 11
# chtc= 3
# rqqc= 3
# crts= 3
# jhjl= 5
# smth= 3
# zdrq= 5
# gfnb= 2
# wdbm= 5
# ffdn= 9
# hzpt= 12
# djzw= hsfc + mqqn
# ppmp= 6
# lfbw= 9
# csvf= 2
# jgtw= 5
# qdwz= 3
# dnht= 8
# cfvg= 2
# qzqb= 2
# hrqb= 4
# tbzm= jcvp + ztsb
# hzrv= 5
# lltl= 2
# tqnb= 4
# qjpt= 5
# gcwj= 1
# nvbp= 3
# lbdz= 3
# jsbf= 13
# djmw= 4
# qbhs= 3
# zvsh= dvrs + mmpr
# gbqf= 3
# mssm= bzsr * dqrz
# wbsc= vlzr + mtjv
# qslg= 2
# ccjr= 13
# qvfj= gbtd * fwzh
# zvcm= 13
# mvmf= 1
# glsj= 7
# fmpq= 2
# pbrm= 2
# rcrs= 3
# vdsg= 15
# wgmj= 2
# mrcm= 5
# vgql= 2
# nmgn= 5
# mpnn= 4
# sjzl= 3
# qbtb= 2
# tmnm= 5
# sfvv= 17
# jngq= 5
# trnb= hzrv * jmls
# gclp= 2
# ltcr= 5
# zlbl= 2
# zgjm= 3
# hccl= 2
# dwgv= 8
# lmch= 2
# hgsq= 7
# hwrj= lgcg + jlpq
# tdln= 9
# qlsv= 2
# htsg= 4
# szqr= bplb + gtcf
# jdvn= 6
# mhbr= 8
# nvvj= 19
# htbz= 3
# rlqh= 5
# pttp= 2
# bmqt= 16
# gvft= 2
# csqw= 3
# grcp= 1
# rbjt= 3
# rdzz= 11
# lzng= 6
# pvff= 2
# nprj= 13
# bwqj= 11
# dmpn= 10
# bbnf= 3
# bfds= 3
# mnsw= lmch * nmgq
# hmmb= 3
# fpmt= 5
# fdlh= 19
# wzft= 2
# qqnj= mhbr * hhjc
# hfgt= 3
# rfjj= 4
# pfvc= 2
# gsvb= 5
# nqqf= 13
# snhj= 5
# wmzc= hthb + lbwh
# dwrp= qlhd + wjjb
# cqsd= 16
# cprm= 4
# bgvn= 16
# ppjn= 3
# tflm= 11
# gqqg= 4
# jfbn= 5
# rrhz= 5
# ptbr= 5
# grnt= 14
# clvq= 6
# tzcc= 5
# vpst= jsbf + zdcb
# tvdj= 5
# cwmr= 2
# wcbz= mljm + pmpv
# lfmh= 3
# jgrj= wnjr * tvtd
# fjlb= 3
# vccn= fplg * lfbw
# sjlb= 2
# lgzj= 9
# svsd= ltzc * bmqt
# fprb= 10
# gnwg= 2
# hltn= 11
# cpnw= 5
# rltv= 4
# qqbt= tmlt * mlnv
# dcmn= 1
# bnzz= 3
# jljz= rrjh * vpbm
# wrvb= 2
# mhzp= 2
# mjcq= jpcf * ndnw
# pbjq= 11
# qgmg= 5
# jbrm= 4
# gvcw= jmdf * bnnb
# bjcd= 2
# gtzg= 2
# brvj= 1
# ftlm= 2
# tmjv= 8
# psbh= 9
# cvzc= 2
# nfgf= 8
# cdmp= 3
# jtls= fcch * hzzt
# dznv= 3
# qvdq= 2
# lpwh= 5
# csns= vmdr * swnp
# wmmf= 5
# qtpq= 3
# fjbz= 3
# zsrg= hpmc * lbcg
# lqwg= 2
# rpqp= 1
# ggds= 2
# jlfq= 1
# gscs= 2
# hqfg= gwwr + pqfz
# zsmq= 3
# pgvf= 5
# nttp= 3
# hrlr= 17
# fwcr= 3
# mjmp= 3
# mflj= 1
# sqds= mjmq + mdfs
# vpwz= 2
# lcps= nmcn * jrwd
# jzrj= 3
# lttb= 3
# jrfv= 4
# fhpf= 2
# mmzq= 3
# cslb= 19
# rvnc= 6
# jsvf= smmv + qbsb
# crbc= 3
# chzm= 2
# cjww= 2
# pfsp= chnh * mrdf
# jbhn= 9
# lzbf= 2
# qbdl= 2
# hqmw= 2
# flft= 2
# ldrb= 5
# fjfv= swfb * whlt
# mgcb= 2
# hhwr= 2
# wvqd= 6
# lvwn= 19
# vnrz= 5
# jcbz= bfpl * vflc
# svth= 9
# fjqv= 2
# djnv= 2
# zlmg= 2
# zshr= 2
# bcch= 2
# jlbl= 2
# qths= 3
# mhzh= 4
# zjjl= 2
# prjp= whfl * wtgl
# cpbb= gbqf + prnq
# wftl= 3
# dlrf= 2
# dbhj= mdsh * scqf
# cplp= 5
# wmph= 3
# csdb= 3
# tvch= 5
# szqs= 15
# qwcv= 11
# dmzn= 5
# hlrh= 1
# fjls= 11
# dldq= 2
# lpjz= 7
# prmn= 10
# vlch= 6
# zmsb= 2
# gfps= 2
# dbjl= 2
# svrr= 3
# mpdd= 3
# fnbp= 4
# jcpc= tzwt * mpnn
# dspt= 3
# lwvz= 5
# rhgh= 3
# nqlc= 3
# mhvf= 7
# gwsl= 7
# lbdd= szvs * pvvz
# jffr= 1
# njdn= 2
# wbvr= 2
# wdrf= cssw + ndtn
# fgcl= tvlv * qlsv
# mlgd= pcch * ggds
# znpj= 5
# pmdv= 15
# tmnv= 3
# pjdw= 4
# ggbt= 18
# flsg= 3
# bjsd= bbgm * wmzc
# ntjv= 9
# mwhv= wbht * fjls
# gsfg= jrqb * fwcr
# nhzf= 12
# cmdn= 2
# mgbq= 17
# pngt= 3
# szss= 5
# zgjb= 4
# sgpd= zsrp / vpfr
# jtmc= 2
# lbgs= zgjb * wfqq
# dctm= 3
# srmz= 4
# fghr= 3
# jtzh= 17
# mgfm= 2
# gjgg= 3
# bcph= vdws * wqst
# gpmj= 2
# tswl= 11
# hwhs= cpnw + fpbv
# jwjr= srmq + jgqz
# stmf= 17
# rrbs= 7
# cbcc= 2
# jnwq= 4
# vmnt= 20
# jvrt= 6
# qpld= 7
# gmhh= 5
# vdpc= 3
# wjrj= nqqf * ttcf
# jccd= 2
# lhnc= 3
# tbcc= 2
# tsvq= zwct * qncq
# lsnd= 7
# wjfh= 2
# tcqc= 11
# slln= bfds * mrsm
# cgdf= 9
# lhnl= 2
# bhqt= zgzp * qcdp
# cnvb= 4
# gpww= gwgn * vtdv
# lljn= 13
# mrdt= sgpd * dghz
# jpjr= 7
# brdb= jbtz * scch
# thpr= 2
# tqjw= 3
# bwdn= 6
# lcjr= 2
# plns= lbdz * qjvh
# vqht= qtpq * zvsh
# lbvw= 9
# bzdz= 14
# qflf= fnbp * mlgd

# %%
lfqf
# Out:
# 4

# %%
while len(Ops) > 0 :
    for i in range(len(Ops)):
        try:
            exec(Ops[i])
            Ops.pop(i)
        except :
            continue

# %%
root
# Out:
# 232974643455000.0

# %%
import re

# %%
test_input = """root: pppw + sjmn
dbpl: 5
cczh: sllz + lgvd
zczc: 2
ptdq: humn - dvpt
dvpt: 3
lfqf: 4
humn: 5
ljgn: 2
sjmn: drzm * dbpl
sllz: 4
pppw: cczh / lfqf
lgvd: ljgn * ptdq
drzm: hmdt - zczc
hmdt: 32"""

# %%
import requests

URL = "https://adventofcode.com/{year}/day/{day}/input"
url = URL.format(year='2022', day=21)
cookies = {"session":"53616c7465645f5fd345d8c12076a357c8d31b2c0c4ad1c152eefbd5c1cf09e0c8d6d7f657fc558887d443d2d07fbc90728ada9b6a91afcecb9926ffb4981a93"}
req = requests.get(url, cookies=cookies)

if req.status_code != 200:
    print("Error. Got status:", req.status_code)
    print(req.text)
    exit(3)
else:
    my_input = req.text

# %%
all_Ops = []
for l in my_input.split("\n") :
    if l == "":
        pass
    
    l= l.replace(":","=")
    
    if l[:4] == "root" :
        m = re.findall("[a-z]{4}",l)
        part1 = m[1]
        part2 = m[2]
        print("\t",part1,part2)
        continue
    if l[:4] == "humn" :
        print("\t",l)
        continue
        
    try :
        exec(l)
        print(l)
    except :
        all_Ops.append(l)
# Out:
# mcbv= 1
# vwnl= 15
# sgzv= 2
# zhrt= 5
# bwhp= 2
# clfd= 4
# rmwq= 11
# mbjq= 5
# lsbb= 11
# mqvz= 6
# dghz= 8
# qncq= 5
# qzfg= 2
# wsqv= 1
# cqgs= 4
# vthp= 5
# cldw= 2
# nmlz= 2
# ggrv= 3
# nglg= 2
# ddpq= 10
# mqzs= 18
# vfnf= 3
# ddlp= 5
# cqtt= 11
# rswb= 3
# tvqp= 4
# plsl= 5
# dfnt= 11
# scvz= 3
# wqst= 14
# fqpq= 3
# nrlz= 7
# lmph= 4
# zfzv= 2
# hcpp= 3
# sgjg= 13
# rhth= 11
# mgln= 2
# gpjt= 2
# cgjn= 3
# bglm= 2
# rcsr= 2
# vrsn= 4
# ldrz= 9
# zdtn= 3
# zffh= 3
# vrch= 15
# zhfp= 2
# zrtm= 2
# lhsz= 2
# nmcn= 5
# vpsw= 3
# jrpz= 3
# zzdc= 2
# pqfz= 3
# zlww= 3
# wfqq= 20
# fpbv= 2
# blgl= 2
# dsfj= 3
# bdnm= 2
# dhsh= 2
# nrmh= 2
# gpvs= 5
# wqbg= 17
# psgh= 2
# scct= 5
# qjmh= 5
# llzr= 3
# sfbz= 2
# qbfv= 4
# bsgr= 4
# hcdz= 10
# qhgq= 4
# dbdm= 11
# fjdm= 7
# zcpr= 3
# zsjz= 2
# zgzp= 3
# hcfd= 3
# vfbp= 2
# jrmf= 10
# vrhr= 5
# wjjb= 17
# wnlb= 1
# drmf= 4
# whfl= 3
# prln= 5
# qhld= 5
# vdql= 4
# gtcf= 4
# lrfq= 4
# nbnn= 3
# ztsb= 2
# zcjs= 12
# jcrg= 4
# sjbs= 2
# hqpv= 2
# vqgq= 19
# znln= 2
# fplg= 3
# qntj= 2
# hthb= 3
# qbsb= 2
# tzwt= 4
# bqvp= 5
# mrsq= 2
# cszc= 5
# tmzb= 9
# snwq= 7
# mzhc= 4
# chjs= 16
# mljm= 12
# pgqf= 1
# pgbv= 3
# gzjv= 2
# zsnd= 2
# sjrq= 2
# prrl= 2
# mlnv= 3
# tglc= 1
# rrrv= 4
# zpqf= 6
# slwd= 8
# bnnb= scvz * rcsr
# rmwn= 3
# nvdr= 2
# pmjb= 15
# zmcl= 19
# zjjh= 2
# cfwb= 3
# fdhh= 4
# swqs= 2
# swrp= 5
# bzwg= 3
# zmrv= 4
# jmls= 19
# dqnz= 3
# dvfs= 2
# qgfv= 4
# fvvg= 18
# fmsm= 19
# qlfl= 1
# wsmh= 20
# gwgf= 2
# ltzc= 4
# rrjh= 8
# lgdh= 3
# wshh= 2
# lvbv= 2
# rpjp= 11
# pdtl= 4
# cpmj= 13
# mgzc= 5
# mhvh= 6
# rdsw= 5
# wvqm= 3
# wnzm= 4
# zbcq= 2
# pvfg= 4
# lgcg= 1
# mjrc= 2
# swfb= 5
# pbzp= 3
# smmv= 5
# dndz= 3
# dwms= 4
# qcqm= 4
# dscj= 2
# jnfs= 2
# vtsb= 6
# ztrh= 2
# lhmd= 3
# lslm= 1
# qmcn= 3
# fzzz= 3
# ndnw= 4
# cmqt= 4
# rfqf= 2
# fqvq= 2
# rscb= 2
# jtwb= 1
# lgfc= 5
# qtzt= 17
# pjvb= 8
# hzzt= 2
# rbwp= 11
# vvcf= 4
# vhgj= 1
# fpdd= 10
# fgts= 4
# mmrh= 15
# zwjz= 3
# grdz= 4
# mpwt= 3
# fmjd= 2
# wtrn= 5
# bzsr= 2
# jpcf= 4
# dhbn= 7
# qqlh= 2
# gdfn= 4
# wrqt= 7
# jtln= 5
# jnqt= 6
# pnnc= 2
# jngl= 20
# qmbc= 2
# fqqp= 2
# lsls= 3
# nsqd= 3
# bdjw= 6
# rwwv= 9
# mjmq= 7
# drlc= 2
# nwhm= 8
# bdtj= 2
# jslc= 2
# bsjw= 5
# hzrc= 3
# bwmt= 3
# phhl= 7
# dtfc= 2
# tmlt= 3
# cgrs= 3
# zzrb= 5
# bdct= 17
# rtsv= 2
# rshw= 6
# pdrq= 5
# tgcm= 12
# stjm= 4
# wrpg= 5
# vlfz= 2
# hcqm= 2
# lwwl= 2
# zrzq= 3
# mdsh= 3
# nlbc= 2
# cfnm= 12
# lhrn= 6
# hlzz= 2
# lgvw= 5
# zpth= 2
# crbb= 2
# mrdf= pjvb + zhrt
# vpnq= vlfz * rpjp
# hdrn= 4
# mpbh= wvqm * scct
# scqf= 2
# nbzl= 6
# jdsl= 2
# fdcg= 2
# zwct= 2
# bvcg= 2
# wtgl= 2
# vmdr= 2
# jmwv= 3
# spnj= 2
# mzqf= 4
# pmpv= 1
# bflc= 1
# vzfq= 5
# nvzv= 3
# fhwg= 3
# vzws= 2
# dlpj= 5
# qmrr= qbfv + rbwp
# nsqp= 12
# bwdr= 11
# srmq= vhgj + sgjg
# vpbm= 3
# jrpd= 2
# hpmc= 5
# zwzh= 2
# fwzh= 3
# zmwg= 3
# vjzr= 2
# drbj= 2
# ftns= 4
# zrbp= 6
# bfpl= 5
# nwph= 7
# pcpc= 2
# cmwj= 9
# gtrn= 5
# sbvs= 12
# nmgq= 6
# ndtn= 11
# pwrd= 11
# dvrs= 5
# qjvh= 3
# mmpr= 8
# hnts= 5
# 	 jwcq swbn
# nrhc= 4
# dfpc= 3
# dsqp= 2
# qznm= 2
# mjqg= 5
# hhjc= 2
# wzmd= 3
# gsjl= 3
# wtwh= 18
# jrwd= 2
# ctlf= 13
# nqhp= 15
# jfhf= 7
# dlgv= 3
# mpgr= 2
# mqqn= 11
# sszs= 2
# jzdl= 3
# jmdf= 12
# nnmm= 2
# mhgr= 3
# jcpn= 2
# sqjg= 3
# whdb= 2
# lbcg= 3
# zdcb= 6
# ntcs= 4
# dhww= 6
# sjqv= 2
# lspl= 12
# mvpr= 11
# znvq= 7
# qcrj= 2
# gftc= vjzr * wrpg
# rbvm= 5
# jpnh= 10
# qrtr= 2
# zrtg= 3
# ndzl= 3
# ctjd= 5
# fhfh= 6
# hqpl= jnfs + ldrz
# srtc= 5
# gjnm= 5
# wbht= 2
# sjqt= 5
# fjnb= 2
# clrc= 14
# wnjr= 11
# bdtq= 3
# swhl= 3
# crbr= 1
# vbsv= 7
# stpr= 5
# tlcv= 19
# hqhd= 8
# wcrn= 2
# grfs= 9
# qwvf= 3
# ghcz= 2
# frmn= 7
# cdtd= 1
# vhqn= 11
# jjpc= 16
# hcrb= 3
# lcbm= 6
# pvvz= 17
# prnq= 4
# jbtz= 13
# sbtw= 11
# ccdv= 3
# cqrn= 2
# jlpq= 9
# slhp= 9
# lpcl= qrtr + dlpj
# shpg= 2
# bbdv= 4
# bwwn= hcfd * pgbv
# jfnb= 3
# rlnm= 4
# gwgn= 3
# fsmf= 3
# dbbn= 5
# tfdf= 2
# fmwm= 2
# nswm= 8
# sjfw= 3
# vflc= 16
# dsbm= 3
# vjjf= 7
# jrqb= 9
# wtdg= 5
# bplb= 3
# brmq= 3
# nbpg= 11
# zfpj= 3
# jlzb= 4
# sgln= nbnn * zwjz
# gdwh= 3
# ltgb= 2
# hwns= 3
# jwdm= 2
# qcwb= 17
# 	 humn= 2411
# bvwh= 2
# stmm= 5
# cssw= qcqm * sjfw
# zvrg= 5
# ghzp= 4
# pzpb= 17
# nbfg= 9
# svsj= wtdg * mvpr
# phcr= 2
# glgp= 2
# pjrz= 3
# nflq= 2
# cnbs= 12
# zrhr= 3
# fmgg= 5
# wjdt= nsqp + zlww
# chnh= 2
# ctml= 3
# nrfs= 1
# tvlv= 5
# pcwb= 3
# zfqv= 6
# nhzn= 17
# tnhj= 5
# jmmc= 5
# rqpc= 11
# hnzp= 11
# lqsc= 4
# jgqz= mmrh * hcpp
# lqqp= 11
# gbtd= 5
# cjgw= 2
# tdlb= 2
# jcjn= 3
# njmh= 6
# lbwh= 4
# pcch= 11
# dphq= 14
# vcql= hqpv * stjm
# hqjm= 4
# dlhh= 7
# njqm= 3
# bdvw= 2
# ffhw= 1
# bnph= 3
# ppfh= 3
# gvgg= 3
# vcbt= 3
# vdws= 2
# hhmp= 6
# nmlv= 14
# pfdz= 3
# dhwj= 7
# vpfr= 2
# cqdn= 3
# jcdg= 2
# szvs= 2
# mdfs= 5
# jlnf= 4
# rtdg= 7
# vlzr= 2
# rglz= 13
# qshz= 2
# mtjv= 5
# vpvj= 2
# lbqf= 2
# ghdj= 2
# rmbl= 3
# vcdl= 2
# pmms= 2
# pqjs= 3
# nwbc= 4
# zvhw= jfnb * znln
# hmdf= 2
# qlhd= 6
# zvpt= 2
# zjds= 6
# grmh= 3
# lbdb= 7
# ftdc= 18
# scch= 5
# hsfc= 12
# mcbf= 1
# zzdg= 2
# mwcq= 4
# zntt= 8
# djnb= 2
# vghf= 2
# wrtj= 1
# gvtg= 3
# bbgm= 13
# pmgv= 3
# drbr= 5
# wgsc= 3
# fcch= 3
# lnpn= 2
# lhpw= 8
# mrsm= 5
# gwwr= 4
# hwcr= drmf * zhfp
# zttd= 2
# dlwm= 7
# hjvn= 4
# pftp= 7
# wfpf= 2
# dqrz= 3
# bfbd= 13
# mdds= 9
# ztgt= 5
# ftmb= 8
# vtdv= 9
# swnp= vcql - jtwb
# ggcf= 9
# mszf= 4
# tgbv= 2
# jcvp= 5
# wprn= 8
# zdmc= 13
# tvtd= 3
# lqvb= 11
# gsjf= 4
# jrbl= 3
# wgtb= 3
# vbft= 13
# lhsg= 4
# zsrp= cpmj + lqqp
# fgtb= 15
# fnnl= 4
# whlt= 2
# wdlg= 4
# cttl= 4
# dgjl= 1
# gmnm= 3
# sqsz= 11
# cdms= 2
# tfmc= 3
# tdws= 2
# ttcf= hcrb * ctlf
# jqhm= 2
# htzv= 5
# qcdp= 3
# pmjv= 11
# chtc= 3
# rqqc= 3
# crts= 3
# jhjl= 5
# smth= 3
# zdrq= 5
# gfnb= 2
# wdbm= 5
# ffdn= 9
# hzpt= 12
# djzw= hsfc + mqqn
# ppmp= 6
# lfbw= 9
# csvf= 2
# jgtw= 5
# qdwz= 3
# dnht= 8
# cfvg= 2
# qzqb= 2
# hrqb= 4
# tbzm= jcvp + ztsb
# hzrv= 5
# lltl= 2
# tqnb= 4
# qjpt= 5
# gcwj= 1
# nvbp= 3
# lbdz= 3
# jsbf= 13
# djmw= 4
# qbhs= 3
# zvsh= dvrs + mmpr
# gbqf= 3
# mssm= bzsr * dqrz
# wbsc= vlzr + mtjv
# qslg= 2
# ccjr= 13
# qvfj= gbtd * fwzh
# zvcm= 13
# mvmf= 1
# glsj= 7
# fmpq= 2
# pbrm= 2
# rcrs= 3
# vdsg= 15
# wgmj= 2
# mrcm= 5
# vgql= 2
# nmgn= 5
# mpnn= 4
# sjzl= 3
# qbtb= 2
# tmnm= 5
# sfvv= 17
# jngq= 5
# trnb= hzrv * jmls
# gclp= 2
# ltcr= 5
# zlbl= 2
# zgjm= 3
# hccl= 2
# dwgv= 8
# lmch= 2
# hgsq= 7
# hwrj= lgcg + jlpq
# tdln= 9
# qlsv= 2
# htsg= 4
# szqr= bplb + gtcf
# jdvn= 6
# mhbr= 8
# nvvj= 19
# htbz= 3
# rlqh= 5
# pttp= 2
# bmqt= 16
# gvft= 2
# csqw= 3
# grcp= 1
# rbjt= 3
# rdzz= 11
# lzng= 6
# pvff= 2
# nprj= 13
# bwqj= 11
# dmpn= 10
# bbnf= 3
# bfds= 3
# mnsw= lmch * nmgq
# hmmb= 3
# fpmt= 5
# fdlh= 19
# wzft= 2
# qqnj= mhbr * hhjc
# hfgt= 3
# rfjj= 4
# pfvc= 2
# gsvb= 5
# nqqf= 13
# snhj= 5
# wmzc= hthb + lbwh
# dwrp= qlhd + wjjb
# cqsd= 16
# cprm= 4
# bgvn= 16
# ppjn= 3
# tflm= 11
# gqqg= 4
# jfbn= 5
# rrhz= 5
# ptbr= 5
# grnt= 14
# clvq= 6
# tzcc= 5
# vpst= jsbf + zdcb
# tvdj= 5
# cwmr= 2
# wcbz= mljm + pmpv
# lfmh= 3
# jgrj= wnjr * tvtd
# fjlb= 3
# vccn= fplg * lfbw
# sjlb= 2
# lgzj= 9
# svsd= ltzc * bmqt
# fprb= 10
# gnwg= 2
# hltn= 11
# cpnw= 5
# rltv= 4
# qqbt= tmlt * mlnv
# dcmn= 1
# bnzz= 3
# jljz= rrjh * vpbm
# wrvb= 2
# mhzp= 2
# mjcq= jpcf * ndnw
# pbjq= 11
# qgmg= 5
# jbrm= 4
# gvcw= jmdf * bnnb
# bjcd= 2
# gtzg= 2
# brvj= 1
# ftlm= 2
# tmjv= 8
# psbh= 9
# cvzc= 2
# nfgf= 8
# cdmp= 3
# jtls= fcch * hzzt
# dznv= 3
# qvdq= 2
# lpwh= 5
# csns= vmdr * swnp
# wmmf= 5
# qtpq= 3
# fjbz= 3
# zsrg= hpmc * lbcg
# lqwg= 2
# rpqp= 1
# ggds= 2
# jlfq= 1
# gscs= 2
# hqfg= gwwr + pqfz
# zsmq= 3
# pgvf= 5
# nttp= 3
# hrlr= 17
# fwcr= 3
# mjmp= 3
# mflj= 1
# sqds= mjmq + mdfs
# vpwz= 2
# lcps= nmcn * jrwd
# jzrj= 3
# lttb= 3
# jrfv= 4
# fhpf= 2
# mmzq= 3
# cslb= 19
# rvnc= 6
# jsvf= smmv + qbsb
# crbc= 3
# chzm= 2
# cjww= 2
# pfsp= chnh * mrdf
# jbhn= 9
# lzbf= 2
# qbdl= 2
# hqmw= 2
# flft= 2
# ldrb= 5
# fjfv= swfb * whlt
# mgcb= 2
# hhwr= 2
# wvqd= 6
# lvwn= 19
# vnrz= 5
# jcbz= bfpl * vflc
# svth= 9
# fjqv= 2
# djnv= 2
# zlmg= 2
# zshr= 2
# bcch= 2
# jlbl= 2
# qths= 3
# mhzh= 4
# zjjl= 2
# prjp= whfl * wtgl
# cpbb= gbqf + prnq
# wftl= 3
# dlrf= 2
# dbhj= mdsh * scqf
# cplp= 5
# wmph= 3
# csdb= 3
# tvch= 5
# szqs= 15
# qwcv= 11
# dmzn= 5
# hlrh= 1
# fjls= 11
# dldq= 2
# lpjz= 7
# prmn= 10
# vlch= 6
# zmsb= 2
# gfps= 2
# dbjl= 2
# svrr= 3
# mpdd= 3
# fnbp= 4
# jcpc= tzwt * mpnn
# dspt= 3
# lwvz= 5
# rhgh= 3
# nqlc= 3
# mhvf= 7
# gwsl= 7
# lbdd= szvs * pvvz
# jffr= 1
# njdn= 2
# wbvr= 2
# wdrf= cssw + ndtn
# fgcl= tvlv * qlsv
# mlgd= pcch * ggds
# znpj= 5
# pmdv= 15
# tmnv= 3
# pjdw= 4
# ggbt= 18
# flsg= 3
# bjsd= bbgm * wmzc
# ntjv= 9
# mwhv= wbht * fjls
# gsfg= jrqb * fwcr
# nhzf= 12
# cmdn= 2
# mgbq= 17
# pngt= 3
# szss= 5
# zgjb= 4
# sgpd= zsrp / vpfr
# jtmc= 2
# lbgs= zgjb * wfqq
# dctm= 3
# srmz= 4
# fghr= 3
# jtzh= 17
# mgfm= 2
# gjgg= 3
# bcph= vdws * wqst
# gpmj= 2
# tswl= 11
# hwhs= cpnw + fpbv
# jwjr= srmq + jgqz
# stmf= 17
# rrbs= 7
# cbcc= 2
# jnwq= 4
# vmnt= 20
# jvrt= 6
# qpld= 7
# gmhh= 5
# vdpc= 3
# wjrj= nqqf * ttcf
# jccd= 2
# lhnc= 3
# tbcc= 2
# tsvq= zwct * qncq
# lsnd= 7
# wjfh= 2
# tcqc= 11
# slln= bfds * mrsm
# cgdf= 9
# lhnl= 2
# bhqt= zgzp * qcdp
# cnvb= 4
# gpww= gwgn * vtdv
# lljn= 13
# mrdt= sgpd * dghz
# jpjr= 7
# brdb= jbtz * scch
# thpr= 2
# tqjw= 3
# bwdn= 6
# lcjr= 2
# plns= lbdz * qjvh
# vqht= qtpq * zvsh
# lbvw= 9
# bzdz= 14
# qflf= fnbp * mlgd

# %%
Ops = all_Ops.copy()

# %%
names_ = set(['humn'])

Inv_Ops = []


while len(Ops) > 0 :

    for i in range(len(Ops)-1,-1,-1):
        m = re.findall("[a-z]{4}",Ops[i])

        if len(names_.intersection(set(m))) >0 :
            op = Ops.pop(i)
            Inv_Ops.append(op)
            for mm in m :
                names_.add(mm)
        else :
            try:
                exec(Ops[i])
                Ops.pop(i)
            except :
                continue

# %%
try:
    t = part1+"="+part2
    exec(t)
    print(t)
except :
    t = part2+"="+part1
    exec(t)
    print(t)
# Out:
# jwcq=swbn

# %%
Inv_Ops
# Out:
# ['nvzf= humn - ptcw',
#  'dbjg= nvzf + rhzd',
#  'ptcw= qlpz * hwcr',
#  'rhzd= rltv + cwmd',
#  'qlpz= qncl + bfwm',
#  'hprt= dbjg / hlzz',
#  'bfwm= ccdv * gpvz',
#  'qncl= qmcn + jzrv',
#  'thvp= mfqj + hprt',
#  'ddjv= zcmw * thvp',
#  'cwmd= wcgj + qvbv',
#  'wvmh= ddjv - dbbn',
#  'rtbj= fmwm * wvmh',
#  'qqsq= mngg + rtbj',
#  'svfw= qqsq / cfwb',
#  'nssz= svfw - mczw',
#  'qrpw= nssz / dctm',
#  'cwcp= qrpw + hglg',
#  'hglg= gmsv - djmf',
#  'vnqc= cwcp * glgp',
#  'rrtz= tljt + vnqc',
#  'nhbv= fmpq * rrtz',
#  'wmsh= nhbv - ddhj',
#  'rpmd= wmsh / bqvp',
#  'wmff= gnph + rpmd',
#  'jmhl= wmff + cfqf',
#  'tqrr= gsmd + jmhl',
#  'mfsc= tqrr / cjww',
#  'mhzc= mfsc - mgmb',
#  'rswz= mhzc * rfqf',
#  'prng= rsqh + rswz',
#  'qvhs= prng * gpvs',
#  'lsgq= qvhs - mrnr',
#  'hbvq= lsgq + hgsv',
#  'fbvb= hbvq + ffmg',
#  'qglg= vffz + fbvb',
#  'vbfg= qglg / vdpc',
#  'rqgl= vbfg + cgqj',
#  'vvfw= rqgl * lwwl',
#  'gjzt= vvfw - hdth',
#  'lrhg= gjzt / jtln',
#  'vjhc= lrhg - hzps',
#  'pqtc= srtc * vjhc',
#  'sbbm= pqtc + tcrd',
#  'ncjl= sbbm / pmgv',
#  'dfhw= wrqt + ncjl',
#  'fcws= dfhw / psbh',
#  'dtdn= fcws - ntrh',
#  'tlgs= dbdm * dtdn',
#  'mqlg= tlgs + lhll',
#  'jpmr= mqlg / nglg',
#  'cfbm= jpmr - qtct',
#  'tffz= lhnl * cfbm',
#  'dpvd= tffz - rtss',
#  'wvhz= dpvd + qdhr',
#  'hfrf= wvhz / jmwv',
#  'mqwl= hfrf + rhmw',
#  'mjhq= dscj * mqwl',
#  'swcg= mjhq - jmdz',
#  'wffv= swcg * njdn',
#  'nrjr= scrb + wffv',
#  'ltsm= nrjr / gclp',
#  'nctz= ltsm + wzhg',
#  'bccm= nctz + fvcp',
#  'vmjq= bccm / nwph',
#  'hgwb= vmjq - phss',
#  'nbjs= hgwb * ppmp',
#  'gzmw= nbjs - rchf',
#  'zlbn= gzmw / dnht',
#  'qvnz= zlbn + hbzq',
#  'mcsj= qvnz * fqmp',
#  'rlcd= mcsj + hnnw',
#  'lbng= ghzp * rlcd',
#  'thfg= lbng - jqzj',
#  'rrbz= thfg / zcfd',
#  'twcj= gwjj - rrbz',
#  'pqnb= twcj / jrfv',
#  'nrwg= pqnb + wznq',
#  'jwcq= nrwg * vpgj']

# %%
while len(Inv_Ops) > 0 :
    
        
    op = Inv_Ops.pop(0)
    
    print(op)
    
    cur_keys = locals().keys()
    m = re.findall("[a-z]{4}",op)

    try :
        exec(op)
    except :
        m0 = m[0]
        m1 = m[1]
        m2 = m[2]
        if m0 in cur_keys :
            if m1 in cur_keys :
                if op[11] == "-" :
                    # m0_k = m1_k - m2_un
                    exec(m2 + "=" + m1 + "-" + m0)
                elif op[11] == "+" :
                    # m0_k = m1_k + m2_un
                    exec(m2 + "=" + m0 + "-" + m1)
                elif op[11] == "*" :
                    # m0_k = m1_k * m2_un
                    exec(m2 + "=" + m0 + "/" + m1)
                elif op[11] == "/" :
                    # m0_k = m1_k / m2_un
                    exec(m2 + "=" + m1 + "/" + m0)
                else :
                    print("Pbm with ",op)
                
                exec("print('\t',"+m[0]+")")
                exec("print('\t',"+m[1]+")")
                exec("print('\t\t',"+m[2]+")")
                continue
            elif m2 in cur_keys :
                if op[11] == "-" :
                    # m0_k = m1_un - m2_k
                    exec(m1 + "=" + m2 + "+" + m0)
                elif op[11] == "+" :
                    # m0_k = m1_uk + m2_k
                    exec(m1 + "=" + m0 + "-" + m2)
                elif op[11] == "*" :
                    # m0_k = m1_uk * m2_k
                    exec(m1 + "=" + m0 + "/" + m2)
                elif op[11] == "/" :
                    # m0_k = m1_uk / m2_k
                    exec(m1 + "=" + m0 + "*" + m2)
                else :
                    print("Pbm with ",op)
                
                exec("print('\t',"+m[0]+")")
                exec("print('\t',"+m[2]+")")
                exec("print('\t\t',"+m[1]+")")
                continue
        Inv_Ops.append(op)
# Out:
# nvzf= humn - ptcw
# dbjg= nvzf + rhzd
# ptcw= qlpz * hwcr
# rhzd= rltv + cwmd
# qlpz= qncl + bfwm
# hprt= dbjg / hlzz
# bfwm= ccdv * gpvz
# qncl= qmcn + jzrv
# thvp= mfqj + hprt
# ddjv= zcmw * thvp
# cwmd= wcgj + qvbv
# wvmh= ddjv - dbbn
# rtbj= fmwm * wvmh
# qqsq= mngg + rtbj
# svfw= qqsq / cfwb
# nssz= svfw - mczw
# qrpw= nssz / dctm
# cwcp= qrpw + hglg
# hglg= gmsv - djmf
# vnqc= cwcp * glgp
# rrtz= tljt + vnqc
# nhbv= fmpq * rrtz
# wmsh= nhbv - ddhj
# rpmd= wmsh / bqvp
# wmff= gnph + rpmd
# jmhl= wmff + cfqf
# tqrr= gsmd + jmhl
# mfsc= tqrr / cjww
# mhzc= mfsc - mgmb
# rswz= mhzc * rfqf
# prng= rsqh + rswz
# qvhs= prng * gpvs
# lsgq= qvhs - mrnr
# hbvq= lsgq + hgsv
# fbvb= hbvq + ffmg
# qglg= vffz + fbvb
# vbfg= qglg / vdpc
# rqgl= vbfg + cgqj
# vvfw= rqgl * lwwl
# gjzt= vvfw - hdth
# lrhg= gjzt / jtln
# vjhc= lrhg - hzps
# pqtc= srtc * vjhc
# sbbm= pqtc + tcrd
# ncjl= sbbm / pmgv
# dfhw= wrqt + ncjl
# fcws= dfhw / psbh
# dtdn= fcws - ntrh
# tlgs= dbdm * dtdn
# mqlg= tlgs + lhll
# jpmr= mqlg / nglg
# cfbm= jpmr - qtct
# tffz= lhnl * cfbm
# dpvd= tffz - rtss
# wvhz= dpvd + qdhr
# hfrf= wvhz / jmwv
# mqwl= hfrf + rhmw
# mjhq= dscj * mqwl
# swcg= mjhq - jmdz
# wffv= swcg * njdn
# nrjr= scrb + wffv
# ltsm= nrjr / gclp
# nctz= ltsm + wzhg
# bccm= nctz + fvcp
# vmjq= bccm / nwph
# hgwb= vmjq - phss
# nbjs= hgwb * ppmp
# gzmw= nbjs - rchf
# zlbn= gzmw / dnht
# qvnz= zlbn + hbzq
# mcsj= qvnz * fqmp
# rlcd= mcsj + hnnw
# lbng= ghzp * rlcd
# thfg= lbng - jqzj
# rrbz= thfg / zcfd
# twcj= gwjj - rrbz
# pqnb= twcj / jrfv
# nrwg= pqnb + wznq
# jwcq= nrwg * vpgj
# 	 72950437237500.0
# 	 30
# 		 2431681241250.0
# nvzf= humn - ptcw
# dbjg= nvzf + rhzd
# ptcw= qlpz * hwcr
# rhzd= rltv + cwmd
# qlpz= qncl + bfwm
# hprt= dbjg / hlzz
# thvp= mfqj + hprt
# ddjv= zcmw * thvp
# wvmh= ddjv - dbbn
# rtbj= fmwm * wvmh
# qqsq= mngg + rtbj
# svfw= qqsq / cfwb
# nssz= svfw - mczw
# qrpw= nssz / dctm
# cwcp= qrpw + hglg
# vnqc= cwcp * glgp
# rrtz= tljt + vnqc
# nhbv= fmpq * rrtz
# wmsh= nhbv - ddhj
# rpmd= wmsh / bqvp
# wmff= gnph + rpmd
# jmhl= wmff + cfqf
# tqrr= gsmd + jmhl
# mfsc= tqrr / cjww
# mhzc= mfsc - mgmb
# rswz= mhzc * rfqf
# prng= rsqh + rswz
# qvhs= prng * gpvs
# lsgq= qvhs - mrnr
# hbvq= lsgq + hgsv
# fbvb= hbvq + ffmg
# qglg= vffz + fbvb
# vbfg= qglg / vdpc
# rqgl= vbfg + cgqj
# vvfw= rqgl * lwwl
# gjzt= vvfw - hdth
# lrhg= gjzt / jtln
# vjhc= lrhg - hzps
# pqtc= srtc * vjhc
# sbbm= pqtc + tcrd
# ncjl= sbbm / pmgv
# dfhw= wrqt + ncjl
# fcws= dfhw / psbh
# dtdn= fcws - ntrh
# tlgs= dbdm * dtdn
# mqlg= tlgs + lhll
# jpmr= mqlg / nglg
# cfbm= jpmr - qtct
# tffz= lhnl * cfbm
# dpvd= tffz - rtss
# wvhz= dpvd + qdhr
# hfrf= wvhz / jmwv
# mqwl= hfrf + rhmw
# mjhq= dscj * mqwl
# swcg= mjhq - jmdz
# wffv= swcg * njdn
# nrjr= scrb + wffv
# ltsm= nrjr / gclp
# nctz= ltsm + wzhg
# bccm= nctz + fvcp
# vmjq= bccm / nwph
# hgwb= vmjq - phss
# nbjs= hgwb * ppmp
# gzmw= nbjs - rchf
# zlbn= gzmw / dnht
# qvnz= zlbn + hbzq
# mcsj= qvnz * fqmp
# rlcd= mcsj + hnnw
# lbng= ghzp * rlcd
# thfg= lbng - jqzj
# rrbz= thfg / zcfd
# twcj= gwjj - rrbz
# pqnb= twcj / jrfv
# nrwg= pqnb + wznq
# 	 2431681241250.0
# 	 215
# 		 2431681241035.0
# nvzf= humn - ptcw
# dbjg= nvzf + rhzd
# ptcw= qlpz * hwcr
# hprt= dbjg / hlzz
# thvp= mfqj + hprt
# ddjv= zcmw * thvp
# wvmh= ddjv - dbbn
# rtbj= fmwm * wvmh
# qqsq= mngg + rtbj
# svfw= qqsq / cfwb
# nssz= svfw - mczw
# qrpw= nssz / dctm
# cwcp= qrpw + hglg
# vnqc= cwcp * glgp
# rrtz= tljt + vnqc
# nhbv= fmpq * rrtz
# wmsh= nhbv - ddhj
# rpmd= wmsh / bqvp
# wmff= gnph + rpmd
# jmhl= wmff + cfqf
# tqrr= gsmd + jmhl
# mfsc= tqrr / cjww
# mhzc= mfsc - mgmb
# rswz= mhzc * rfqf
# prng= rsqh + rswz
# qvhs= prng * gpvs
# lsgq= qvhs - mrnr
# hbvq= lsgq + hgsv
# fbvb= hbvq + ffmg
# qglg= vffz + fbvb
# vbfg= qglg / vdpc
# rqgl= vbfg + cgqj
# vvfw= rqgl * lwwl
# gjzt= vvfw - hdth
# lrhg= gjzt / jtln
# vjhc= lrhg - hzps
# pqtc= srtc * vjhc
# sbbm= pqtc + tcrd
# ncjl= sbbm / pmgv
# dfhw= wrqt + ncjl
# fcws= dfhw / psbh
# dtdn= fcws - ntrh
# tlgs= dbdm * dtdn
# mqlg= tlgs + lhll
# jpmr= mqlg / nglg
# cfbm= jpmr - qtct
# tffz= lhnl * cfbm
# dpvd= tffz - rtss
# wvhz= dpvd + qdhr
# hfrf= wvhz / jmwv
# mqwl= hfrf + rhmw
# mjhq= dscj * mqwl
# swcg= mjhq - jmdz
# wffv= swcg * njdn
# nrjr= scrb + wffv
# ltsm= nrjr / gclp
# nctz= ltsm + wzhg
# bccm= nctz + fvcp
# vmjq= bccm / nwph
# hgwb= vmjq - phss
# nbjs= hgwb * ppmp
# gzmw= nbjs - rchf
# zlbn= gzmw / dnht
# qvnz= zlbn + hbzq
# mcsj= qvnz * fqmp
# rlcd= mcsj + hnnw
# lbng= ghzp * rlcd
# thfg= lbng - jqzj
# rrbz= thfg / zcfd
# twcj= gwjj - rrbz
# pqnb= twcj / jrfv
# 	 2431681241035.0
# 	 4
# 		 9726724964140.0
# nvzf= humn - ptcw
# dbjg= nvzf + rhzd
# hprt= dbjg / hlzz
# thvp= mfqj + hprt
# ddjv= zcmw * thvp
# wvmh= ddjv - dbbn
# rtbj= fmwm * wvmh
# qqsq= mngg + rtbj
# svfw= qqsq / cfwb
# nssz= svfw - mczw
# qrpw= nssz / dctm
# cwcp= qrpw + hglg
# vnqc= cwcp * glgp
# rrtz= tljt + vnqc
# nhbv= fmpq * rrtz
# wmsh= nhbv - ddhj
# rpmd= wmsh / bqvp
# wmff= gnph + rpmd
# jmhl= wmff + cfqf
# tqrr= gsmd + jmhl
# mfsc= tqrr / cjww
# mhzc= mfsc - mgmb
# rswz= mhzc * rfqf
# prng= rsqh + rswz
# qvhs= prng * gpvs
# lsgq= qvhs - mrnr
# hbvq= lsgq + hgsv
# fbvb= hbvq + ffmg
# qglg= vffz + fbvb
# vbfg= qglg / vdpc
# rqgl= vbfg + cgqj
# vvfw= rqgl * lwwl
# gjzt= vvfw - hdth
# lrhg= gjzt / jtln
# vjhc= lrhg - hzps
# pqtc= srtc * vjhc
# sbbm= pqtc + tcrd
# ncjl= sbbm / pmgv
# dfhw= wrqt + ncjl
# fcws= dfhw / psbh
# dtdn= fcws - ntrh
# tlgs= dbdm * dtdn
# mqlg= tlgs + lhll
# jpmr= mqlg / nglg
# cfbm= jpmr - qtct
# tffz= lhnl * cfbm
# dpvd= tffz - rtss
# wvhz= dpvd + qdhr
# hfrf= wvhz / jmwv
# mqwl= hfrf + rhmw
# mjhq= dscj * mqwl
# swcg= mjhq - jmdz
# wffv= swcg * njdn
# nrjr= scrb + wffv
# ltsm= nrjr / gclp
# nctz= ltsm + wzhg
# bccm= nctz + fvcp
# vmjq= bccm / nwph
# hgwb= vmjq - phss
# nbjs= hgwb * ppmp
# gzmw= nbjs - rchf
# zlbn= gzmw / dnht
# qvnz= zlbn + hbzq
# mcsj= qvnz * fqmp
# rlcd= mcsj + hnnw
# lbng= ghzp * rlcd
# thfg= lbng - jqzj
# rrbz= thfg / zcfd
# twcj= gwjj - rrbz
# 	 9726724964140.0
# 	 21336560836613.0
# 		 11609835872473.0
# nvzf= humn - ptcw
# dbjg= nvzf + rhzd
# hprt= dbjg / hlzz
# thvp= mfqj + hprt
# ddjv= zcmw * thvp
# wvmh= ddjv - dbbn
# rtbj= fmwm * wvmh
# qqsq= mngg + rtbj
# svfw= qqsq / cfwb
# nssz= svfw - mczw
# qrpw= nssz / dctm
# cwcp= qrpw + hglg
# vnqc= cwcp * glgp
# rrtz= tljt + vnqc
# nhbv= fmpq * rrtz
# wmsh= nhbv - ddhj
# rpmd= wmsh / bqvp
# wmff= gnph + rpmd
# jmhl= wmff + cfqf
# tqrr= gsmd + jmhl
# mfsc= tqrr / cjww
# mhzc= mfsc - mgmb
# rswz= mhzc * rfqf
# prng= rsqh + rswz
# qvhs= prng * gpvs
# lsgq= qvhs - mrnr
# hbvq= lsgq + hgsv
# fbvb= hbvq + ffmg
# qglg= vffz + fbvb
# vbfg= qglg / vdpc
# rqgl= vbfg + cgqj
# vvfw= rqgl * lwwl
# gjzt= vvfw - hdth
# lrhg= gjzt / jtln
# vjhc= lrhg - hzps
# pqtc= srtc * vjhc
# sbbm= pqtc + tcrd
# ncjl= sbbm / pmgv
# dfhw= wrqt + ncjl
# fcws= dfhw / psbh
# dtdn= fcws - ntrh
# tlgs= dbdm * dtdn
# mqlg= tlgs + lhll
# jpmr= mqlg / nglg
# cfbm= jpmr - qtct
# tffz= lhnl * cfbm
# dpvd= tffz - rtss
# wvhz= dpvd + qdhr
# hfrf= wvhz / jmwv
# mqwl= hfrf + rhmw
# mjhq= dscj * mqwl
# swcg= mjhq - jmdz
# wffv= swcg * njdn
# nrjr= scrb + wffv
# ltsm= nrjr / gclp
# nctz= ltsm + wzhg
# bccm= nctz + fvcp
# vmjq= bccm / nwph
# hgwb= vmjq - phss
# nbjs= hgwb * ppmp
# gzmw= nbjs - rchf
# zlbn= gzmw / dnht
# qvnz= zlbn + hbzq
# mcsj= qvnz * fqmp
# rlcd= mcsj + hnnw
# lbng= ghzp * rlcd
# thfg= lbng - jqzj
# rrbz= thfg / zcfd
# 	 11609835872473.0
# 	 7
# 		 81268851107311.0
# nvzf= humn - ptcw
# dbjg= nvzf + rhzd
# hprt= dbjg / hlzz
# thvp= mfqj + hprt
# ddjv= zcmw * thvp
# wvmh= ddjv - dbbn
# rtbj= fmwm * wvmh
# qqsq= mngg + rtbj
# svfw= qqsq / cfwb
# nssz= svfw - mczw
# qrpw= nssz / dctm
# cwcp= qrpw + hglg
# vnqc= cwcp * glgp
# rrtz= tljt + vnqc
# nhbv= fmpq * rrtz
# wmsh= nhbv - ddhj
# rpmd= wmsh / bqvp
# wmff= gnph + rpmd
# jmhl= wmff + cfqf
# tqrr= gsmd + jmhl
# mfsc= tqrr / cjww
# mhzc= mfsc - mgmb
# rswz= mhzc * rfqf
# prng= rsqh + rswz
# qvhs= prng * gpvs
# lsgq= qvhs - mrnr
# hbvq= lsgq + hgsv
# fbvb= hbvq + ffmg
# qglg= vffz + fbvb
# vbfg= qglg / vdpc
# rqgl= vbfg + cgqj
# vvfw= rqgl * lwwl
# gjzt= vvfw - hdth
# lrhg= gjzt / jtln
# vjhc= lrhg - hzps
# pqtc= srtc * vjhc
# sbbm= pqtc + tcrd
# ncjl= sbbm / pmgv
# dfhw= wrqt + ncjl
# fcws= dfhw / psbh
# dtdn= fcws - ntrh
# tlgs= dbdm * dtdn
# mqlg= tlgs + lhll
# jpmr= mqlg / nglg
# cfbm= jpmr - qtct
# tffz= lhnl * cfbm
# dpvd= tffz - rtss
# wvhz= dpvd + qdhr
# hfrf= wvhz / jmwv
# mqwl= hfrf + rhmw
# mjhq= dscj * mqwl
# swcg= mjhq - jmdz
# wffv= swcg * njdn
# nrjr= scrb + wffv
# ltsm= nrjr / gclp
# nctz= ltsm + wzhg
# bccm= nctz + fvcp
# vmjq= bccm / nwph
# hgwb= vmjq - phss
# nbjs= hgwb * ppmp
# gzmw= nbjs - rchf
# zlbn= gzmw / dnht
# qvnz= zlbn + hbzq
# mcsj= qvnz * fqmp
# rlcd= mcsj + hnnw
# lbng= ghzp * rlcd
# thfg= lbng - jqzj
# 	 81268851107311.0
# 	 325
# 		 81268851107636.0
# nvzf= humn - ptcw
# dbjg= nvzf + rhzd
# hprt= dbjg / hlzz
# thvp= mfqj + hprt
# ddjv= zcmw * thvp
# wvmh= ddjv - dbbn
# rtbj= fmwm * wvmh
# qqsq= mngg + rtbj
# svfw= qqsq / cfwb
# nssz= svfw - mczw
# qrpw= nssz / dctm
# cwcp= qrpw + hglg
# vnqc= cwcp * glgp
# rrtz= tljt + vnqc
# nhbv= fmpq * rrtz
# wmsh= nhbv - ddhj
# rpmd= wmsh / bqvp
# wmff= gnph + rpmd
# jmhl= wmff + cfqf
# tqrr= gsmd + jmhl
# mfsc= tqrr / cjww
# mhzc= mfsc - mgmb
# rswz= mhzc * rfqf
# prng= rsqh + rswz
# qvhs= prng * gpvs
# lsgq= qvhs - mrnr
# hbvq= lsgq + hgsv
# fbvb= hbvq + ffmg
# qglg= vffz + fbvb
# vbfg= qglg / vdpc
# rqgl= vbfg + cgqj
# vvfw= rqgl * lwwl
# gjzt= vvfw - hdth
# lrhg= gjzt / jtln
# vjhc= lrhg - hzps
# pqtc= srtc * vjhc
# sbbm= pqtc + tcrd
# ncjl= sbbm / pmgv
# dfhw= wrqt + ncjl
# fcws= dfhw / psbh
# dtdn= fcws - ntrh
# tlgs= dbdm * dtdn
# mqlg= tlgs + lhll
# jpmr= mqlg / nglg
# cfbm= jpmr - qtct
# tffz= lhnl * cfbm
# dpvd= tffz - rtss
# wvhz= dpvd + qdhr
# hfrf= wvhz / jmwv
# mqwl= hfrf + rhmw
# mjhq= dscj * mqwl
# swcg= mjhq - jmdz
# wffv= swcg * njdn
# nrjr= scrb + wffv
# ltsm= nrjr / gclp
# nctz= ltsm + wzhg
# bccm= nctz + fvcp
# vmjq= bccm / nwph
# hgwb= vmjq - phss
# nbjs= hgwb * ppmp
# gzmw= nbjs - rchf
# zlbn= gzmw / dnht
# qvnz= zlbn + hbzq
# mcsj= qvnz * fqmp
# rlcd= mcsj + hnnw
# lbng= ghzp * rlcd
# 	 81268851107636.0
# 	 4
# 		 20317212776909.0
# nvzf= humn - ptcw
# dbjg= nvzf + rhzd
# hprt= dbjg / hlzz
# thvp= mfqj + hprt
# ddjv= zcmw * thvp
# wvmh= ddjv - dbbn
# rtbj= fmwm * wvmh
# qqsq= mngg + rtbj
# svfw= qqsq / cfwb
# nssz= svfw - mczw
# qrpw= nssz / dctm
# cwcp= qrpw + hglg
# vnqc= cwcp * glgp
# rrtz= tljt + vnqc
# nhbv= fmpq * rrtz
# wmsh= nhbv - ddhj
# rpmd= wmsh / bqvp
# wmff= gnph + rpmd
# jmhl= wmff + cfqf
# tqrr= gsmd + jmhl
# mfsc= tqrr / cjww
# mhzc= mfsc - mgmb
# rswz= mhzc * rfqf
# prng= rsqh + rswz
# qvhs= prng * gpvs
# lsgq= qvhs - mrnr
# hbvq= lsgq + hgsv
# fbvb= hbvq + ffmg
# qglg= vffz + fbvb
# vbfg= qglg / vdpc
# rqgl= vbfg + cgqj
# vvfw= rqgl * lwwl
# gjzt= vvfw - hdth
# lrhg= gjzt / jtln
# vjhc= lrhg - hzps
# pqtc= srtc * vjhc
# sbbm= pqtc + tcrd
# ncjl= sbbm / pmgv
# dfhw= wrqt + ncjl
# fcws= dfhw / psbh
# dtdn= fcws - ntrh
# tlgs= dbdm * dtdn
# mqlg= tlgs + lhll
# jpmr= mqlg / nglg
# cfbm= jpmr - qtct
# tffz= lhnl * cfbm
# dpvd= tffz - rtss
# wvhz= dpvd + qdhr
# hfrf= wvhz / jmwv
# mqwl= hfrf + rhmw
# mjhq= dscj * mqwl
# swcg= mjhq - jmdz
# wffv= swcg * njdn
# nrjr= scrb + wffv
# ltsm= nrjr / gclp
# nctz= ltsm + wzhg
# bccm= nctz + fvcp
# vmjq= bccm / nwph
# hgwb= vmjq - phss
# nbjs= hgwb * ppmp
# gzmw= nbjs - rchf
# zlbn= gzmw / dnht
# qvnz= zlbn + hbzq
# mcsj= qvnz * fqmp
# rlcd= mcsj + hnnw
# 	 20317212776909.0
# 	 9
# 		 20317212776900.0
# nvzf= humn - ptcw
# dbjg= nvzf + rhzd
# hprt= dbjg / hlzz
# thvp= mfqj + hprt
# ddjv= zcmw * thvp
# wvmh= ddjv - dbbn
# rtbj= fmwm * wvmh
# qqsq= mngg + rtbj
# svfw= qqsq / cfwb
# nssz= svfw - mczw
# qrpw= nssz / dctm
# cwcp= qrpw + hglg
# vnqc= cwcp * glgp
# rrtz= tljt + vnqc
# nhbv= fmpq * rrtz
# wmsh= nhbv - ddhj
# rpmd= wmsh / bqvp
# wmff= gnph + rpmd
# jmhl= wmff + cfqf
# tqrr= gsmd + jmhl
# mfsc= tqrr / cjww
# mhzc= mfsc - mgmb
# rswz= mhzc * rfqf
# prng= rsqh + rswz
# qvhs= prng * gpvs
# lsgq= qvhs - mrnr
# hbvq= lsgq + hgsv
# fbvb= hbvq + ffmg
# qglg= vffz + fbvb
# vbfg= qglg / vdpc
# rqgl= vbfg + cgqj
# vvfw= rqgl * lwwl
# gjzt= vvfw - hdth
# lrhg= gjzt / jtln
# vjhc= lrhg - hzps
# pqtc= srtc * vjhc
# sbbm= pqtc + tcrd
# ncjl= sbbm / pmgv
# dfhw= wrqt + ncjl
# fcws= dfhw / psbh
# dtdn= fcws - ntrh
# tlgs= dbdm * dtdn
# mqlg= tlgs + lhll
# jpmr= mqlg / nglg
# cfbm= jpmr - qtct
# tffz= lhnl * cfbm
# dpvd= tffz - rtss
# wvhz= dpvd + qdhr
# hfrf= wvhz / jmwv
# mqwl= hfrf + rhmw
# mjhq= dscj * mqwl
# swcg= mjhq - jmdz
# wffv= swcg * njdn
# nrjr= scrb + wffv
# ltsm= nrjr / gclp
# nctz= ltsm + wzhg
# bccm= nctz + fvcp
# vmjq= bccm / nwph
# hgwb= vmjq - phss
# nbjs= hgwb * ppmp
# gzmw= nbjs - rchf
# zlbn= gzmw / dnht
# qvnz= zlbn + hbzq
# mcsj= qvnz * fqmp
# 	 20317212776900.0
# 	 10
# 		 2031721277690.0
# nvzf= humn - ptcw
# dbjg= nvzf + rhzd
# hprt= dbjg / hlzz
# thvp= mfqj + hprt
# ddjv= zcmw * thvp
# wvmh= ddjv - dbbn
# rtbj= fmwm * wvmh
# qqsq= mngg + rtbj
# svfw= qqsq / cfwb
# nssz= svfw - mczw
# qrpw= nssz / dctm
# cwcp= qrpw + hglg
# vnqc= cwcp * glgp
# rrtz= tljt + vnqc
# nhbv= fmpq * rrtz
# wmsh= nhbv - ddhj
# rpmd= wmsh / bqvp
# wmff= gnph + rpmd
# jmhl= wmff + cfqf
# tqrr= gsmd + jmhl
# mfsc= tqrr / cjww
# mhzc= mfsc - mgmb
# rswz= mhzc * rfqf
# prng= rsqh + rswz
# qvhs= prng * gpvs
# lsgq= qvhs - mrnr
# hbvq= lsgq + hgsv
# fbvb= hbvq + ffmg
# qglg= vffz + fbvb
# vbfg= qglg / vdpc
# rqgl= vbfg + cgqj
# vvfw= rqgl * lwwl
# gjzt= vvfw - hdth
# lrhg= gjzt / jtln
# vjhc= lrhg - hzps
# pqtc= srtc * vjhc
# sbbm= pqtc + tcrd
# ncjl= sbbm / pmgv
# dfhw= wrqt + ncjl
# fcws= dfhw / psbh
# dtdn= fcws - ntrh
# tlgs= dbdm * dtdn
# mqlg= tlgs + lhll
# jpmr= mqlg / nglg
# cfbm= jpmr - qtct
# tffz= lhnl * cfbm
# dpvd= tffz - rtss
# wvhz= dpvd + qdhr
# hfrf= wvhz / jmwv
# mqwl= hfrf + rhmw
# mjhq= dscj * mqwl
# swcg= mjhq - jmdz
# wffv= swcg * njdn
# nrjr= scrb + wffv
# ltsm= nrjr / gclp
# nctz= ltsm + wzhg
# bccm= nctz + fvcp
# vmjq= bccm / nwph
# hgwb= vmjq - phss
# nbjs= hgwb * ppmp
# gzmw= nbjs - rchf
# zlbn= gzmw / dnht
# qvnz= zlbn + hbzq
# 	 2031721277690.0
# 	 639
# 		 2031721277051.0
# nvzf= humn - ptcw
# dbjg= nvzf + rhzd
# hprt= dbjg / hlzz
# thvp= mfqj + hprt
# ddjv= zcmw * thvp
# wvmh= ddjv - dbbn
# rtbj= fmwm * wvmh
# qqsq= mngg + rtbj
# svfw= qqsq / cfwb
# nssz= svfw - mczw
# qrpw= nssz / dctm
# cwcp= qrpw + hglg
# vnqc= cwcp * glgp
# rrtz= tljt + vnqc
# nhbv= fmpq * rrtz
# wmsh= nhbv - ddhj
# rpmd= wmsh / bqvp
# wmff= gnph + rpmd
# jmhl= wmff + cfqf
# tqrr= gsmd + jmhl
# mfsc= tqrr / cjww
# mhzc= mfsc - mgmb
# rswz= mhzc * rfqf
# prng= rsqh + rswz
# qvhs= prng * gpvs
# lsgq= qvhs - mrnr
# hbvq= lsgq + hgsv
# fbvb= hbvq + ffmg
# qglg= vffz + fbvb
# vbfg= qglg / vdpc
# rqgl= vbfg + cgqj
# vvfw= rqgl * lwwl
# gjzt= vvfw - hdth
# lrhg= gjzt / jtln
# vjhc= lrhg - hzps
# pqtc= srtc * vjhc
# sbbm= pqtc + tcrd
# ncjl= sbbm / pmgv
# dfhw= wrqt + ncjl
# fcws= dfhw / psbh
# dtdn= fcws - ntrh
# tlgs= dbdm * dtdn
# mqlg= tlgs + lhll
# jpmr= mqlg / nglg
# cfbm= jpmr - qtct
# tffz= lhnl * cfbm
# dpvd= tffz - rtss
# wvhz= dpvd + qdhr
# hfrf= wvhz / jmwv
# mqwl= hfrf + rhmw
# mjhq= dscj * mqwl
# swcg= mjhq - jmdz
# wffv= swcg * njdn
# nrjr= scrb + wffv
# ltsm= nrjr / gclp
# nctz= ltsm + wzhg
# bccm= nctz + fvcp
# vmjq= bccm / nwph
# hgwb= vmjq - phss
# nbjs= hgwb * ppmp
# gzmw= nbjs - rchf
# zlbn= gzmw / dnht
# 	 2031721277051.0
# 	 8
# 		 16253770216408.0
# nvzf= humn - ptcw
# dbjg= nvzf + rhzd
# hprt= dbjg / hlzz
# thvp= mfqj + hprt
# ddjv= zcmw * thvp
# wvmh= ddjv - dbbn
# rtbj= fmwm * wvmh
# qqsq= mngg + rtbj
# svfw= qqsq / cfwb
# nssz= svfw - mczw
# qrpw= nssz / dctm
# cwcp= qrpw + hglg
# vnqc= cwcp * glgp
# rrtz= tljt + vnqc
# nhbv= fmpq * rrtz
# wmsh= nhbv - ddhj
# rpmd= wmsh / bqvp
# wmff= gnph + rpmd
# jmhl= wmff + cfqf
# tqrr= gsmd + jmhl
# mfsc= tqrr / cjww
# mhzc= mfsc - mgmb
# rswz= mhzc * rfqf
# prng= rsqh + rswz
# qvhs= prng * gpvs
# lsgq= qvhs - mrnr
# hbvq= lsgq + hgsv
# fbvb= hbvq + ffmg
# qglg= vffz + fbvb
# vbfg= qglg / vdpc
# rqgl= vbfg + cgqj
# vvfw= rqgl * lwwl
# gjzt= vvfw - hdth
# lrhg= gjzt / jtln
# vjhc= lrhg - hzps
# pqtc= srtc * vjhc
# sbbm= pqtc + tcrd
# ncjl= sbbm / pmgv
# dfhw= wrqt + ncjl
# fcws= dfhw / psbh
# dtdn= fcws - ntrh
# tlgs= dbdm * dtdn
# mqlg= tlgs + lhll
# jpmr= mqlg / nglg
# cfbm= jpmr - qtct
# tffz= lhnl * cfbm
# dpvd= tffz - rtss
# wvhz= dpvd + qdhr
# hfrf= wvhz / jmwv
# mqwl= hfrf + rhmw
# mjhq= dscj * mqwl
# swcg= mjhq - jmdz
# wffv= swcg * njdn
# nrjr= scrb + wffv
# ltsm= nrjr / gclp
# nctz= ltsm + wzhg
# bccm= nctz + fvcp
# vmjq= bccm / nwph
# hgwb= vmjq - phss
# nbjs= hgwb * ppmp
# gzmw= nbjs - rchf
# 	 16253770216408.0
# 	 626.0
# 		 16253770217034.0
# nvzf= humn - ptcw
# dbjg= nvzf + rhzd
# hprt= dbjg / hlzz
# thvp= mfqj + hprt
# ddjv= zcmw * thvp
# wvmh= ddjv - dbbn
# rtbj= fmwm * wvmh
# qqsq= mngg + rtbj
# svfw= qqsq / cfwb
# nssz= svfw - mczw
# qrpw= nssz / dctm
# cwcp= qrpw + hglg
# vnqc= cwcp * glgp
# rrtz= tljt + vnqc
# nhbv= fmpq * rrtz
# wmsh= nhbv - ddhj
# rpmd= wmsh / bqvp
# wmff= gnph + rpmd
# jmhl= wmff + cfqf
# tqrr= gsmd + jmhl
# mfsc= tqrr / cjww
# mhzc= mfsc - mgmb
# rswz= mhzc * rfqf
# prng= rsqh + rswz
# qvhs= prng * gpvs
# lsgq= qvhs - mrnr
# hbvq= lsgq + hgsv
# fbvb= hbvq + ffmg
# qglg= vffz + fbvb
# vbfg= qglg / vdpc
# rqgl= vbfg + cgqj
# vvfw= rqgl * lwwl
# gjzt= vvfw - hdth
# lrhg= gjzt / jtln
# vjhc= lrhg - hzps
# pqtc= srtc * vjhc
# sbbm= pqtc + tcrd
# ncjl= sbbm / pmgv
# dfhw= wrqt + ncjl
# fcws= dfhw / psbh
# dtdn= fcws - ntrh
# tlgs= dbdm * dtdn
# mqlg= tlgs + lhll
# jpmr= mqlg / nglg
# cfbm= jpmr - qtct
# tffz= lhnl * cfbm
# dpvd= tffz - rtss
# wvhz= dpvd + qdhr
# hfrf= wvhz / jmwv
# mqwl= hfrf + rhmw
# mjhq= dscj * mqwl
# swcg= mjhq - jmdz
# wffv= swcg * njdn
# nrjr= scrb + wffv
# ltsm= nrjr / gclp
# nctz= ltsm + wzhg
# bccm= nctz + fvcp
# vmjq= bccm / nwph
# hgwb= vmjq - phss
# nbjs= hgwb * ppmp
# 	 16253770217034.0
# 	 6
# 		 2708961702839.0
# nvzf= humn - ptcw
# dbjg= nvzf + rhzd
# hprt= dbjg / hlzz
# thvp= mfqj + hprt
# ddjv= zcmw * thvp
# wvmh= ddjv - dbbn
# rtbj= fmwm * wvmh
# qqsq= mngg + rtbj
# svfw= qqsq / cfwb
# nssz= svfw - mczw
# qrpw= nssz / dctm
# cwcp= qrpw + hglg
# vnqc= cwcp * glgp
# rrtz= tljt + vnqc
# nhbv= fmpq * rrtz
# wmsh= nhbv - ddhj
# rpmd= wmsh / bqvp
# wmff= gnph + rpmd
# jmhl= wmff + cfqf
# tqrr= gsmd + jmhl
# mfsc= tqrr / cjww
# mhzc= mfsc - mgmb
# rswz= mhzc * rfqf
# prng= rsqh + rswz
# qvhs= prng * gpvs
# lsgq= qvhs - mrnr
# hbvq= lsgq + hgsv
# fbvb= hbvq + ffmg
# qglg= vffz + fbvb
# vbfg= qglg / vdpc
# rqgl= vbfg + cgqj
# vvfw= rqgl * lwwl
# gjzt= vvfw - hdth
# lrhg= gjzt / jtln
# vjhc= lrhg - hzps
# pqtc= srtc * vjhc
# sbbm= pqtc + tcrd
# ncjl= sbbm / pmgv
# dfhw= wrqt + ncjl
# fcws= dfhw / psbh
# dtdn= fcws - ntrh
# tlgs= dbdm * dtdn
# mqlg= tlgs + lhll
# jpmr= mqlg / nglg
# cfbm= jpmr - qtct
# tffz= lhnl * cfbm
# dpvd= tffz - rtss
# wvhz= dpvd + qdhr
# hfrf= wvhz / jmwv
# mqwl= hfrf + rhmw
# mjhq= dscj * mqwl
# swcg= mjhq - jmdz
# wffv= swcg * njdn
# nrjr= scrb + wffv
# ltsm= nrjr / gclp
# nctz= ltsm + wzhg
# bccm= nctz + fvcp
# vmjq= bccm / nwph
# hgwb= vmjq - phss
# 	 2708961702839.0
# 	 582.0
# 		 2708961703421.0
# nvzf= humn - ptcw
# dbjg= nvzf + rhzd
# hprt= dbjg / hlzz
# thvp= mfqj + hprt
# ddjv= zcmw * thvp
# wvmh= ddjv - dbbn
# rtbj= fmwm * wvmh
# qqsq= mngg + rtbj
# svfw= qqsq / cfwb
# nssz= svfw - mczw
# qrpw= nssz / dctm
# cwcp= qrpw + hglg
# vnqc= cwcp * glgp
# rrtz= tljt + vnqc
# nhbv= fmpq * rrtz
# wmsh= nhbv - ddhj
# rpmd= wmsh / bqvp
# wmff= gnph + rpmd
# jmhl= wmff + cfqf
# tqrr= gsmd + jmhl
# mfsc= tqrr / cjww
# mhzc= mfsc - mgmb
# rswz= mhzc * rfqf
# prng= rsqh + rswz
# qvhs= prng * gpvs
# lsgq= qvhs - mrnr
# hbvq= lsgq + hgsv
# fbvb= hbvq + ffmg
# qglg= vffz + fbvb
# vbfg= qglg / vdpc
# rqgl= vbfg + cgqj
# vvfw= rqgl * lwwl
# gjzt= vvfw - hdth
# lrhg= gjzt / jtln
# vjhc= lrhg - hzps
# pqtc= srtc * vjhc
# sbbm= pqtc + tcrd
# ncjl= sbbm / pmgv
# dfhw= wrqt + ncjl
# fcws= dfhw / psbh
# dtdn= fcws - ntrh
# tlgs= dbdm * dtdn
# mqlg= tlgs + lhll
# jpmr= mqlg / nglg
# cfbm= jpmr - qtct
# tffz= lhnl * cfbm
# dpvd= tffz - rtss
# wvhz= dpvd + qdhr
# hfrf= wvhz / jmwv
# mqwl= hfrf + rhmw
# mjhq= dscj * mqwl
# swcg= mjhq - jmdz
# wffv= swcg * njdn
# nrjr= scrb + wffv
# ltsm= nrjr / gclp
# nctz= ltsm + wzhg
# bccm= nctz + fvcp
# vmjq= bccm / nwph
# 	 2708961703421.0
# 	 7
# 		 18962731923947.0
# nvzf= humn - ptcw
# dbjg= nvzf + rhzd
# hprt= dbjg / hlzz
# thvp= mfqj + hprt
# ddjv= zcmw * thvp
# wvmh= ddjv - dbbn
# rtbj= fmwm * wvmh
# qqsq= mngg + rtbj
# svfw= qqsq / cfwb
# nssz= svfw - mczw
# qrpw= nssz / dctm
# cwcp= qrpw + hglg
# vnqc= cwcp * glgp
# rrtz= tljt + vnqc
# nhbv= fmpq * rrtz
# wmsh= nhbv - ddhj
# rpmd= wmsh / bqvp
# wmff= gnph + rpmd
# jmhl= wmff + cfqf
# tqrr= gsmd + jmhl
# mfsc= tqrr / cjww
# mhzc= mfsc - mgmb
# rswz= mhzc * rfqf
# prng= rsqh + rswz
# qvhs= prng * gpvs
# lsgq= qvhs - mrnr
# hbvq= lsgq + hgsv
# fbvb= hbvq + ffmg
# qglg= vffz + fbvb
# vbfg= qglg / vdpc
# rqgl= vbfg + cgqj
# vvfw= rqgl * lwwl
# gjzt= vvfw - hdth
# lrhg= gjzt / jtln
# vjhc= lrhg - hzps
# pqtc= srtc * vjhc
# sbbm= pqtc + tcrd
# ncjl= sbbm / pmgv
# dfhw= wrqt + ncjl
# fcws= dfhw / psbh
# dtdn= fcws - ntrh
# tlgs= dbdm * dtdn
# mqlg= tlgs + lhll
# jpmr= mqlg / nglg
# cfbm= jpmr - qtct
# tffz= lhnl * cfbm
# dpvd= tffz - rtss
# wvhz= dpvd + qdhr
# hfrf= wvhz / jmwv
# mqwl= hfrf + rhmw
# mjhq= dscj * mqwl
# swcg= mjhq - jmdz
# wffv= swcg * njdn
# nrjr= scrb + wffv
# ltsm= nrjr / gclp
# nctz= ltsm + wzhg
# bccm= nctz + fvcp
# 	 18962731923947.0
# 	 16
# 		 18962731923931.0
# nvzf= humn - ptcw
# dbjg= nvzf + rhzd
# hprt= dbjg / hlzz
# thvp= mfqj + hprt
# ddjv= zcmw * thvp
# wvmh= ddjv - dbbn
# rtbj= fmwm * wvmh
# qqsq= mngg + rtbj
# svfw= qqsq / cfwb
# nssz= svfw - mczw
# qrpw= nssz / dctm
# cwcp= qrpw + hglg
# vnqc= cwcp * glgp
# rrtz= tljt + vnqc
# nhbv= fmpq * rrtz
# wmsh= nhbv - ddhj
# rpmd= wmsh / bqvp
# wmff= gnph + rpmd
# jmhl= wmff + cfqf
# tqrr= gsmd + jmhl
# mfsc= tqrr / cjww
# mhzc= mfsc - mgmb
# rswz= mhzc * rfqf
# prng= rsqh + rswz
# qvhs= prng * gpvs
# lsgq= qvhs - mrnr
# hbvq= lsgq + hgsv
# fbvb= hbvq + ffmg
# qglg= vffz + fbvb
# vbfg= qglg / vdpc
# rqgl= vbfg + cgqj
# vvfw= rqgl * lwwl
# gjzt= vvfw - hdth
# lrhg= gjzt / jtln
# vjhc= lrhg - hzps
# pqtc= srtc * vjhc
# sbbm= pqtc + tcrd
# ncjl= sbbm / pmgv
# dfhw= wrqt + ncjl
# fcws= dfhw / psbh
# dtdn= fcws - ntrh
# tlgs= dbdm * dtdn
# mqlg= tlgs + lhll
# jpmr= mqlg / nglg
# cfbm= jpmr - qtct
# tffz= lhnl * cfbm
# dpvd= tffz - rtss
# wvhz= dpvd + qdhr
# hfrf= wvhz / jmwv
# mqwl= hfrf + rhmw
# mjhq= dscj * mqwl
# swcg= mjhq - jmdz
# wffv= swcg * njdn
# nrjr= scrb + wffv
# ltsm= nrjr / gclp
# nctz= ltsm + wzhg
# 	 18962731923931.0
# 	 327
# 		 18962731923604.0
# nvzf= humn - ptcw
# dbjg= nvzf + rhzd
# hprt= dbjg / hlzz
# thvp= mfqj + hprt
# ddjv= zcmw * thvp
# wvmh= ddjv - dbbn
# rtbj= fmwm * wvmh
# qqsq= mngg + rtbj
# svfw= qqsq / cfwb
# nssz= svfw - mczw
# qrpw= nssz / dctm
# cwcp= qrpw + hglg
# vnqc= cwcp * glgp
# rrtz= tljt + vnqc
# nhbv= fmpq * rrtz
# wmsh= nhbv - ddhj
# rpmd= wmsh / bqvp
# wmff= gnph + rpmd
# jmhl= wmff + cfqf
# tqrr= gsmd + jmhl
# mfsc= tqrr / cjww
# mhzc= mfsc - mgmb
# rswz= mhzc * rfqf
# prng= rsqh + rswz
# qvhs= prng * gpvs
# lsgq= qvhs - mrnr
# hbvq= lsgq + hgsv
# fbvb= hbvq + ffmg
# qglg= vffz + fbvb
# vbfg= qglg / vdpc
# rqgl= vbfg + cgqj
# vvfw= rqgl * lwwl
# gjzt= vvfw - hdth
# lrhg= gjzt / jtln
# vjhc= lrhg - hzps
# pqtc= srtc * vjhc
# sbbm= pqtc + tcrd
# ncjl= sbbm / pmgv
# dfhw= wrqt + ncjl
# fcws= dfhw / psbh
# dtdn= fcws - ntrh
# tlgs= dbdm * dtdn
# mqlg= tlgs + lhll
# jpmr= mqlg / nglg
# cfbm= jpmr - qtct
# tffz= lhnl * cfbm
# dpvd= tffz - rtss
# wvhz= dpvd + qdhr
# hfrf= wvhz / jmwv
# mqwl= hfrf + rhmw
# mjhq= dscj * mqwl
# swcg= mjhq - jmdz
# wffv= swcg * njdn
# nrjr= scrb + wffv
# ltsm= nrjr / gclp
# 	 18962731923604.0
# 	 2
# 		 37925463847208.0
# nvzf= humn - ptcw
# dbjg= nvzf + rhzd
# hprt= dbjg / hlzz
# thvp= mfqj + hprt
# ddjv= zcmw * thvp
# wvmh= ddjv - dbbn
# rtbj= fmwm * wvmh
# qqsq= mngg + rtbj
# svfw= qqsq / cfwb
# nssz= svfw - mczw
# qrpw= nssz / dctm
# cwcp= qrpw + hglg
# vnqc= cwcp * glgp
# rrtz= tljt + vnqc
# nhbv= fmpq * rrtz
# wmsh= nhbv - ddhj
# rpmd= wmsh / bqvp
# wmff= gnph + rpmd
# jmhl= wmff + cfqf
# tqrr= gsmd + jmhl
# mfsc= tqrr / cjww
# mhzc= mfsc - mgmb
# rswz= mhzc * rfqf
# prng= rsqh + rswz
# qvhs= prng * gpvs
# lsgq= qvhs - mrnr
# hbvq= lsgq + hgsv
# fbvb= hbvq + ffmg
# qglg= vffz + fbvb
# vbfg= qglg / vdpc
# rqgl= vbfg + cgqj
# vvfw= rqgl * lwwl
# gjzt= vvfw - hdth
# lrhg= gjzt / jtln
# vjhc= lrhg - hzps
# pqtc= srtc * vjhc
# sbbm= pqtc + tcrd
# ncjl= sbbm / pmgv
# dfhw= wrqt + ncjl
# fcws= dfhw / psbh
# dtdn= fcws - ntrh
# tlgs= dbdm * dtdn
# mqlg= tlgs + lhll
# jpmr= mqlg / nglg
# cfbm= jpmr - qtct
# tffz= lhnl * cfbm
# dpvd= tffz - rtss
# wvhz= dpvd + qdhr
# hfrf= wvhz / jmwv
# mqwl= hfrf + rhmw
# mjhq= dscj * mqwl
# swcg= mjhq - jmdz
# wffv= swcg * njdn
# nrjr= scrb + wffv
# 	 37925463847208.0
# 	 160
# 		 37925463847048.0
# nvzf= humn - ptcw
# dbjg= nvzf + rhzd
# hprt= dbjg / hlzz
# thvp= mfqj + hprt
# ddjv= zcmw * thvp
# wvmh= ddjv - dbbn
# rtbj= fmwm * wvmh
# qqsq= mngg + rtbj
# svfw= qqsq / cfwb
# nssz= svfw - mczw
# qrpw= nssz / dctm
# cwcp= qrpw + hglg
# vnqc= cwcp * glgp
# rrtz= tljt + vnqc
# nhbv= fmpq * rrtz
# wmsh= nhbv - ddhj
# rpmd= wmsh / bqvp
# wmff= gnph + rpmd
# jmhl= wmff + cfqf
# tqrr= gsmd + jmhl
# mfsc= tqrr / cjww
# mhzc= mfsc - mgmb
# rswz= mhzc * rfqf
# prng= rsqh + rswz
# qvhs= prng * gpvs
# lsgq= qvhs - mrnr
# hbvq= lsgq + hgsv
# fbvb= hbvq + ffmg
# qglg= vffz + fbvb
# vbfg= qglg / vdpc
# rqgl= vbfg + cgqj
# vvfw= rqgl * lwwl
# gjzt= vvfw - hdth
# lrhg= gjzt / jtln
# vjhc= lrhg - hzps
# pqtc= srtc * vjhc
# sbbm= pqtc + tcrd
# ncjl= sbbm / pmgv
# dfhw= wrqt + ncjl
# fcws= dfhw / psbh
# dtdn= fcws - ntrh
# tlgs= dbdm * dtdn
# mqlg= tlgs + lhll
# jpmr= mqlg / nglg
# cfbm= jpmr - qtct
# tffz= lhnl * cfbm
# dpvd= tffz - rtss
# wvhz= dpvd + qdhr
# hfrf= wvhz / jmwv
# mqwl= hfrf + rhmw
# mjhq= dscj * mqwl
# swcg= mjhq - jmdz
# wffv= swcg * njdn
# 	 37925463847048.0
# 	 2
# 		 18962731923524.0
# nvzf= humn - ptcw
# dbjg= nvzf + rhzd
# hprt= dbjg / hlzz
# thvp= mfqj + hprt
# ddjv= zcmw * thvp
# wvmh= ddjv - dbbn
# rtbj= fmwm * wvmh
# qqsq= mngg + rtbj
# svfw= qqsq / cfwb
# nssz= svfw - mczw
# qrpw= nssz / dctm
# cwcp= qrpw + hglg
# vnqc= cwcp * glgp
# rrtz= tljt + vnqc
# nhbv= fmpq * rrtz
# wmsh= nhbv - ddhj
# rpmd= wmsh / bqvp
# wmff= gnph + rpmd
# jmhl= wmff + cfqf
# tqrr= gsmd + jmhl
# mfsc= tqrr / cjww
# mhzc= mfsc - mgmb
# rswz= mhzc * rfqf
# prng= rsqh + rswz
# qvhs= prng * gpvs
# lsgq= qvhs - mrnr
# hbvq= lsgq + hgsv
# fbvb= hbvq + ffmg
# qglg= vffz + fbvb
# vbfg= qglg / vdpc
# rqgl= vbfg + cgqj
# vvfw= rqgl * lwwl
# gjzt= vvfw - hdth
# lrhg= gjzt / jtln
# vjhc= lrhg - hzps
# pqtc= srtc * vjhc
# sbbm= pqtc + tcrd
# ncjl= sbbm / pmgv
# dfhw= wrqt + ncjl
# fcws= dfhw / psbh
# dtdn= fcws - ntrh
# tlgs= dbdm * dtdn
# mqlg= tlgs + lhll
# jpmr= mqlg / nglg
# cfbm= jpmr - qtct
# tffz= lhnl * cfbm
# dpvd= tffz - rtss
# wvhz= dpvd + qdhr
# hfrf= wvhz / jmwv
# mqwl= hfrf + rhmw
# mjhq= dscj * mqwl
# swcg= mjhq - jmdz
# 	 18962731923524.0
# 	 750
# 		 18962731924274.0
# nvzf= humn - ptcw
# dbjg= nvzf + rhzd
# hprt= dbjg / hlzz
# thvp= mfqj + hprt
# ddjv= zcmw * thvp
# wvmh= ddjv - dbbn
# rtbj= fmwm * wvmh
# qqsq= mngg + rtbj
# svfw= qqsq / cfwb
# nssz= svfw - mczw
# qrpw= nssz / dctm
# cwcp= qrpw + hglg
# vnqc= cwcp * glgp
# rrtz= tljt + vnqc
# nhbv= fmpq * rrtz
# wmsh= nhbv - ddhj
# rpmd= wmsh / bqvp
# wmff= gnph + rpmd
# jmhl= wmff + cfqf
# tqrr= gsmd + jmhl
# mfsc= tqrr / cjww
# mhzc= mfsc - mgmb
# rswz= mhzc * rfqf
# prng= rsqh + rswz
# qvhs= prng * gpvs
# lsgq= qvhs - mrnr
# hbvq= lsgq + hgsv
# fbvb= hbvq + ffmg
# qglg= vffz + fbvb
# vbfg= qglg / vdpc
# rqgl= vbfg + cgqj
# vvfw= rqgl * lwwl
# gjzt= vvfw - hdth
# lrhg= gjzt / jtln
# vjhc= lrhg - hzps
# pqtc= srtc * vjhc
# sbbm= pqtc + tcrd
# ncjl= sbbm / pmgv
# dfhw= wrqt + ncjl
# fcws= dfhw / psbh
# dtdn= fcws - ntrh
# tlgs= dbdm * dtdn
# mqlg= tlgs + lhll
# jpmr= mqlg / nglg
# cfbm= jpmr - qtct
# tffz= lhnl * cfbm
# dpvd= tffz - rtss
# wvhz= dpvd + qdhr
# hfrf= wvhz / jmwv
# mqwl= hfrf + rhmw
# mjhq= dscj * mqwl
# 	 18962731924274.0
# 	 2
# 		 9481365962137.0
# nvzf= humn - ptcw
# dbjg= nvzf + rhzd
# hprt= dbjg / hlzz
# thvp= mfqj + hprt
# ddjv= zcmw * thvp
# wvmh= ddjv - dbbn
# rtbj= fmwm * wvmh
# qqsq= mngg + rtbj
# svfw= qqsq / cfwb
# nssz= svfw - mczw
# qrpw= nssz / dctm
# cwcp= qrpw + hglg
# vnqc= cwcp * glgp
# rrtz= tljt + vnqc
# nhbv= fmpq * rrtz
# wmsh= nhbv - ddhj
# rpmd= wmsh / bqvp
# wmff= gnph + rpmd
# jmhl= wmff + cfqf
# tqrr= gsmd + jmhl
# mfsc= tqrr / cjww
# mhzc= mfsc - mgmb
# rswz= mhzc * rfqf
# prng= rsqh + rswz
# qvhs= prng * gpvs
# lsgq= qvhs - mrnr
# hbvq= lsgq + hgsv
# fbvb= hbvq + ffmg
# qglg= vffz + fbvb
# vbfg= qglg / vdpc
# rqgl= vbfg + cgqj
# vvfw= rqgl * lwwl
# gjzt= vvfw - hdth
# lrhg= gjzt / jtln
# vjhc= lrhg - hzps
# pqtc= srtc * vjhc
# sbbm= pqtc + tcrd
# ncjl= sbbm / pmgv
# dfhw= wrqt + ncjl
# fcws= dfhw / psbh
# dtdn= fcws - ntrh
# tlgs= dbdm * dtdn
# mqlg= tlgs + lhll
# jpmr= mqlg / nglg
# cfbm= jpmr - qtct
# tffz= lhnl * cfbm
# dpvd= tffz - rtss
# wvhz= dpvd + qdhr
# hfrf= wvhz / jmwv
# mqwl= hfrf + rhmw
# 	 9481365962137.0
# 	 756
# 		 9481365961381.0
# nvzf= humn - ptcw
# dbjg= nvzf + rhzd
# hprt= dbjg / hlzz
# thvp= mfqj + hprt
# ddjv= zcmw * thvp
# wvmh= ddjv - dbbn
# rtbj= fmwm * wvmh
# qqsq= mngg + rtbj
# svfw= qqsq / cfwb
# nssz= svfw - mczw
# qrpw= nssz / dctm
# cwcp= qrpw + hglg
# vnqc= cwcp * glgp
# rrtz= tljt + vnqc
# nhbv= fmpq * rrtz
# wmsh= nhbv - ddhj
# rpmd= wmsh / bqvp
# wmff= gnph + rpmd
# jmhl= wmff + cfqf
# tqrr= gsmd + jmhl
# mfsc= tqrr / cjww
# mhzc= mfsc - mgmb
# rswz= mhzc * rfqf
# prng= rsqh + rswz
# qvhs= prng * gpvs
# lsgq= qvhs - mrnr
# hbvq= lsgq + hgsv
# fbvb= hbvq + ffmg
# qglg= vffz + fbvb
# vbfg= qglg / vdpc
# rqgl= vbfg + cgqj
# vvfw= rqgl * lwwl
# gjzt= vvfw - hdth
# lrhg= gjzt / jtln
# vjhc= lrhg - hzps
# pqtc= srtc * vjhc
# sbbm= pqtc + tcrd
# ncjl= sbbm / pmgv
# dfhw= wrqt + ncjl
# fcws= dfhw / psbh
# dtdn= fcws - ntrh
# tlgs= dbdm * dtdn
# mqlg= tlgs + lhll
# jpmr= mqlg / nglg
# cfbm= jpmr - qtct
# tffz= lhnl * cfbm
# dpvd= tffz - rtss
# wvhz= dpvd + qdhr
# hfrf= wvhz / jmwv
# 	 9481365961381.0
# 	 3
# 		 28444097884143.0
# nvzf= humn - ptcw
# dbjg= nvzf + rhzd
# hprt= dbjg / hlzz
# thvp= mfqj + hprt
# ddjv= zcmw * thvp
# wvmh= ddjv - dbbn
# rtbj= fmwm * wvmh
# qqsq= mngg + rtbj
# svfw= qqsq / cfwb
# nssz= svfw - mczw
# qrpw= nssz / dctm
# cwcp= qrpw + hglg
# vnqc= cwcp * glgp
# rrtz= tljt + vnqc
# nhbv= fmpq * rrtz
# wmsh= nhbv - ddhj
# rpmd= wmsh / bqvp
# wmff= gnph + rpmd
# jmhl= wmff + cfqf
# tqrr= gsmd + jmhl
# mfsc= tqrr / cjww
# mhzc= mfsc - mgmb
# rswz= mhzc * rfqf
# prng= rsqh + rswz
# qvhs= prng * gpvs
# lsgq= qvhs - mrnr
# hbvq= lsgq + hgsv
# fbvb= hbvq + ffmg
# qglg= vffz + fbvb
# vbfg= qglg / vdpc
# rqgl= vbfg + cgqj
# vvfw= rqgl * lwwl
# gjzt= vvfw - hdth
# lrhg= gjzt / jtln
# vjhc= lrhg - hzps
# pqtc= srtc * vjhc
# sbbm= pqtc + tcrd
# ncjl= sbbm / pmgv
# dfhw= wrqt + ncjl
# fcws= dfhw / psbh
# dtdn= fcws - ntrh
# tlgs= dbdm * dtdn
# mqlg= tlgs + lhll
# jpmr= mqlg / nglg
# cfbm= jpmr - qtct
# tffz= lhnl * cfbm
# dpvd= tffz - rtss
# wvhz= dpvd + qdhr
# 	 28444097884143.0
# 	 472
# 		 28444097883671.0
# nvzf= humn - ptcw
# dbjg= nvzf + rhzd
# hprt= dbjg / hlzz
# thvp= mfqj + hprt
# ddjv= zcmw * thvp
# wvmh= ddjv - dbbn
# rtbj= fmwm * wvmh
# qqsq= mngg + rtbj
# svfw= qqsq / cfwb
# nssz= svfw - mczw
# qrpw= nssz / dctm
# cwcp= qrpw + hglg
# vnqc= cwcp * glgp
# rrtz= tljt + vnqc
# nhbv= fmpq * rrtz
# wmsh= nhbv - ddhj
# rpmd= wmsh / bqvp
# wmff= gnph + rpmd
# jmhl= wmff + cfqf
# tqrr= gsmd + jmhl
# mfsc= tqrr / cjww
# mhzc= mfsc - mgmb
# rswz= mhzc * rfqf
# prng= rsqh + rswz
# qvhs= prng * gpvs
# lsgq= qvhs - mrnr
# hbvq= lsgq + hgsv
# fbvb= hbvq + ffmg
# qglg= vffz + fbvb
# vbfg= qglg / vdpc
# rqgl= vbfg + cgqj
# vvfw= rqgl * lwwl
# gjzt= vvfw - hdth
# lrhg= gjzt / jtln
# vjhc= lrhg - hzps
# pqtc= srtc * vjhc
# sbbm= pqtc + tcrd
# ncjl= sbbm / pmgv
# dfhw= wrqt + ncjl
# fcws= dfhw / psbh
# dtdn= fcws - ntrh
# tlgs= dbdm * dtdn
# mqlg= tlgs + lhll
# jpmr= mqlg / nglg
# cfbm= jpmr - qtct
# tffz= lhnl * cfbm
# dpvd= tffz - rtss
# 	 28444097883671.0
# 	 377.0
# 		 28444097884048.0
# nvzf= humn - ptcw
# dbjg= nvzf + rhzd
# hprt= dbjg / hlzz
# thvp= mfqj + hprt
# ddjv= zcmw * thvp
# wvmh= ddjv - dbbn
# rtbj= fmwm * wvmh
# qqsq= mngg + rtbj
# svfw= qqsq / cfwb
# nssz= svfw - mczw
# qrpw= nssz / dctm
# cwcp= qrpw + hglg
# vnqc= cwcp * glgp
# rrtz= tljt + vnqc
# nhbv= fmpq * rrtz
# wmsh= nhbv - ddhj
# rpmd= wmsh / bqvp
# wmff= gnph + rpmd
# jmhl= wmff + cfqf
# tqrr= gsmd + jmhl
# mfsc= tqrr / cjww
# mhzc= mfsc - mgmb
# rswz= mhzc * rfqf
# prng= rsqh + rswz
# qvhs= prng * gpvs
# lsgq= qvhs - mrnr
# hbvq= lsgq + hgsv
# fbvb= hbvq + ffmg
# qglg= vffz + fbvb
# vbfg= qglg / vdpc
# rqgl= vbfg + cgqj
# vvfw= rqgl * lwwl
# gjzt= vvfw - hdth
# lrhg= gjzt / jtln
# vjhc= lrhg - hzps
# pqtc= srtc * vjhc
# sbbm= pqtc + tcrd
# ncjl= sbbm / pmgv
# dfhw= wrqt + ncjl
# fcws= dfhw / psbh
# dtdn= fcws - ntrh
# tlgs= dbdm * dtdn
# mqlg= tlgs + lhll
# jpmr= mqlg / nglg
# cfbm= jpmr - qtct
# tffz= lhnl * cfbm
# 	 28444097884048.0
# 	 2
# 		 14222048942024.0
# nvzf= humn - ptcw
# dbjg= nvzf + rhzd
# hprt= dbjg / hlzz
# thvp= mfqj + hprt
# ddjv= zcmw * thvp
# wvmh= ddjv - dbbn
# rtbj= fmwm * wvmh
# qqsq= mngg + rtbj
# svfw= qqsq / cfwb
# nssz= svfw - mczw
# qrpw= nssz / dctm
# cwcp= qrpw + hglg
# vnqc= cwcp * glgp
# rrtz= tljt + vnqc
# nhbv= fmpq * rrtz
# wmsh= nhbv - ddhj
# rpmd= wmsh / bqvp
# wmff= gnph + rpmd
# jmhl= wmff + cfqf
# tqrr= gsmd + jmhl
# mfsc= tqrr / cjww
# mhzc= mfsc - mgmb
# rswz= mhzc * rfqf
# prng= rsqh + rswz
# qvhs= prng * gpvs
# lsgq= qvhs - mrnr
# hbvq= lsgq + hgsv
# fbvb= hbvq + ffmg
# qglg= vffz + fbvb
# vbfg= qglg / vdpc
# rqgl= vbfg + cgqj
# vvfw= rqgl * lwwl
# gjzt= vvfw - hdth
# lrhg= gjzt / jtln
# vjhc= lrhg - hzps
# pqtc= srtc * vjhc
# sbbm= pqtc + tcrd
# ncjl= sbbm / pmgv
# dfhw= wrqt + ncjl
# fcws= dfhw / psbh
# dtdn= fcws - ntrh
# tlgs= dbdm * dtdn
# mqlg= tlgs + lhll
# jpmr= mqlg / nglg
# cfbm= jpmr - qtct
# 	 14222048942024.0
# 	 513
# 		 14222048942537.0
# nvzf= humn - ptcw
# dbjg= nvzf + rhzd
# hprt= dbjg / hlzz
# thvp= mfqj + hprt
# ddjv= zcmw * thvp
# wvmh= ddjv - dbbn
# rtbj= fmwm * wvmh
# qqsq= mngg + rtbj
# svfw= qqsq / cfwb
# nssz= svfw - mczw
# qrpw= nssz / dctm
# cwcp= qrpw + hglg
# vnqc= cwcp * glgp
# rrtz= tljt + vnqc
# nhbv= fmpq * rrtz
# wmsh= nhbv - ddhj
# rpmd= wmsh / bqvp
# wmff= gnph + rpmd
# jmhl= wmff + cfqf
# tqrr= gsmd + jmhl
# mfsc= tqrr / cjww
# mhzc= mfsc - mgmb
# rswz= mhzc * rfqf
# prng= rsqh + rswz
# qvhs= prng * gpvs
# lsgq= qvhs - mrnr
# hbvq= lsgq + hgsv
# fbvb= hbvq + ffmg
# qglg= vffz + fbvb
# vbfg= qglg / vdpc
# rqgl= vbfg + cgqj
# vvfw= rqgl * lwwl
# gjzt= vvfw - hdth
# lrhg= gjzt / jtln
# vjhc= lrhg - hzps
# pqtc= srtc * vjhc
# sbbm= pqtc + tcrd
# ncjl= sbbm / pmgv
# dfhw= wrqt + ncjl
# fcws= dfhw / psbh
# dtdn= fcws - ntrh
# tlgs= dbdm * dtdn
# mqlg= tlgs + lhll
# jpmr= mqlg / nglg
# 	 14222048942537.0
# 	 2
# 		 28444097885074.0
# nvzf= humn - ptcw
# dbjg= nvzf + rhzd
# hprt= dbjg / hlzz
# thvp= mfqj + hprt
# ddjv= zcmw * thvp
# wvmh= ddjv - dbbn
# rtbj= fmwm * wvmh
# qqsq= mngg + rtbj
# svfw= qqsq / cfwb
# nssz= svfw - mczw
# qrpw= nssz / dctm
# cwcp= qrpw + hglg
# vnqc= cwcp * glgp
# rrtz= tljt + vnqc
# nhbv= fmpq * rrtz
# wmsh= nhbv - ddhj
# rpmd= wmsh / bqvp
# wmff= gnph + rpmd
# jmhl= wmff + cfqf
# tqrr= gsmd + jmhl
# mfsc= tqrr / cjww
# mhzc= mfsc - mgmb
# rswz= mhzc * rfqf
# prng= rsqh + rswz
# qvhs= prng * gpvs
# lsgq= qvhs - mrnr
# hbvq= lsgq + hgsv
# fbvb= hbvq + ffmg
# qglg= vffz + fbvb
# vbfg= qglg / vdpc
# rqgl= vbfg + cgqj
# vvfw= rqgl * lwwl
# gjzt= vvfw - hdth
# lrhg= gjzt / jtln
# vjhc= lrhg - hzps
# pqtc= srtc * vjhc
# sbbm= pqtc + tcrd
# ncjl= sbbm / pmgv
# dfhw= wrqt + ncjl
# fcws= dfhw / psbh
# dtdn= fcws - ntrh
# tlgs= dbdm * dtdn
# mqlg= tlgs + lhll
# 	 28444097885074.0
# 	 839
# 		 28444097884235.0
# nvzf= humn - ptcw
# dbjg= nvzf + rhzd
# hprt= dbjg / hlzz
# thvp= mfqj + hprt
# ddjv= zcmw * thvp
# wvmh= ddjv - dbbn
# rtbj= fmwm * wvmh
# qqsq= mngg + rtbj
# svfw= qqsq / cfwb
# nssz= svfw - mczw
# qrpw= nssz / dctm
# cwcp= qrpw + hglg
# vnqc= cwcp * glgp
# rrtz= tljt + vnqc
# nhbv= fmpq * rrtz
# wmsh= nhbv - ddhj
# rpmd= wmsh / bqvp
# wmff= gnph + rpmd
# jmhl= wmff + cfqf
# tqrr= gsmd + jmhl
# mfsc= tqrr / cjww
# mhzc= mfsc - mgmb
# rswz= mhzc * rfqf
# prng= rsqh + rswz
# qvhs= prng * gpvs
# lsgq= qvhs - mrnr
# hbvq= lsgq + hgsv
# fbvb= hbvq + ffmg
# qglg= vffz + fbvb
# vbfg= qglg / vdpc
# rqgl= vbfg + cgqj
# vvfw= rqgl * lwwl
# gjzt= vvfw - hdth
# lrhg= gjzt / jtln
# vjhc= lrhg - hzps
# pqtc= srtc * vjhc
# sbbm= pqtc + tcrd
# ncjl= sbbm / pmgv
# dfhw= wrqt + ncjl
# fcws= dfhw / psbh
# dtdn= fcws - ntrh
# tlgs= dbdm * dtdn
# 	 28444097884235.0
# 	 11
# 		 2585827080385.0
# nvzf= humn - ptcw
# dbjg= nvzf + rhzd
# hprt= dbjg / hlzz
# thvp= mfqj + hprt
# ddjv= zcmw * thvp
# wvmh= ddjv - dbbn
# rtbj= fmwm * wvmh
# qqsq= mngg + rtbj
# svfw= qqsq / cfwb
# nssz= svfw - mczw
# qrpw= nssz / dctm
# cwcp= qrpw + hglg
# vnqc= cwcp * glgp
# rrtz= tljt + vnqc
# nhbv= fmpq * rrtz
# wmsh= nhbv - ddhj
# rpmd= wmsh / bqvp
# wmff= gnph + rpmd
# jmhl= wmff + cfqf
# tqrr= gsmd + jmhl
# mfsc= tqrr / cjww
# mhzc= mfsc - mgmb
# rswz= mhzc * rfqf
# prng= rsqh + rswz
# qvhs= prng * gpvs
# lsgq= qvhs - mrnr
# hbvq= lsgq + hgsv
# fbvb= hbvq + ffmg
# qglg= vffz + fbvb
# vbfg= qglg / vdpc
# rqgl= vbfg + cgqj
# vvfw= rqgl * lwwl
# gjzt= vvfw - hdth
# lrhg= gjzt / jtln
# vjhc= lrhg - hzps
# pqtc= srtc * vjhc
# sbbm= pqtc + tcrd
# ncjl= sbbm / pmgv
# dfhw= wrqt + ncjl
# fcws= dfhw / psbh
# dtdn= fcws - ntrh
# 	 2585827080385.0
# 	 603
# 		 2585827080988.0
# nvzf= humn - ptcw
# dbjg= nvzf + rhzd
# hprt= dbjg / hlzz
# thvp= mfqj + hprt
# ddjv= zcmw * thvp
# wvmh= ddjv - dbbn
# rtbj= fmwm * wvmh
# qqsq= mngg + rtbj
# svfw= qqsq / cfwb
# nssz= svfw - mczw
# qrpw= nssz / dctm
# cwcp= qrpw + hglg
# vnqc= cwcp * glgp
# rrtz= tljt + vnqc
# nhbv= fmpq * rrtz
# wmsh= nhbv - ddhj
# rpmd= wmsh / bqvp
# wmff= gnph + rpmd
# jmhl= wmff + cfqf
# tqrr= gsmd + jmhl
# mfsc= tqrr / cjww
# mhzc= mfsc - mgmb
# rswz= mhzc * rfqf
# prng= rsqh + rswz
# qvhs= prng * gpvs
# lsgq= qvhs - mrnr
# hbvq= lsgq + hgsv
# fbvb= hbvq + ffmg
# qglg= vffz + fbvb
# vbfg= qglg / vdpc
# rqgl= vbfg + cgqj
# vvfw= rqgl * lwwl
# gjzt= vvfw - hdth
# lrhg= gjzt / jtln
# vjhc= lrhg - hzps
# pqtc= srtc * vjhc
# sbbm= pqtc + tcrd
# ncjl= sbbm / pmgv
# dfhw= wrqt + ncjl
# fcws= dfhw / psbh
# 	 2585827080988.0
# 	 9
# 		 23272443728892.0
# nvzf= humn - ptcw
# dbjg= nvzf + rhzd
# hprt= dbjg / hlzz
# thvp= mfqj + hprt
# ddjv= zcmw * thvp
# wvmh= ddjv - dbbn
# rtbj= fmwm * wvmh
# qqsq= mngg + rtbj
# svfw= qqsq / cfwb
# nssz= svfw - mczw
# qrpw= nssz / dctm
# cwcp= qrpw + hglg
# vnqc= cwcp * glgp
# rrtz= tljt + vnqc
# nhbv= fmpq * rrtz
# wmsh= nhbv - ddhj
# rpmd= wmsh / bqvp
# wmff= gnph + rpmd
# jmhl= wmff + cfqf
# tqrr= gsmd + jmhl
# mfsc= tqrr / cjww
# mhzc= mfsc - mgmb
# rswz= mhzc * rfqf
# prng= rsqh + rswz
# qvhs= prng * gpvs
# lsgq= qvhs - mrnr
# hbvq= lsgq + hgsv
# fbvb= hbvq + ffmg
# qglg= vffz + fbvb
# vbfg= qglg / vdpc
# rqgl= vbfg + cgqj
# vvfw= rqgl * lwwl
# gjzt= vvfw - hdth
# lrhg= gjzt / jtln
# vjhc= lrhg - hzps
# pqtc= srtc * vjhc
# sbbm= pqtc + tcrd
# ncjl= sbbm / pmgv
# dfhw= wrqt + ncjl
# 	 23272443728892.0
# 	 7
# 		 23272443728885.0
# nvzf= humn - ptcw
# dbjg= nvzf + rhzd
# hprt= dbjg / hlzz
# thvp= mfqj + hprt
# ddjv= zcmw * thvp
# wvmh= ddjv - dbbn
# rtbj= fmwm * wvmh
# qqsq= mngg + rtbj
# svfw= qqsq / cfwb
# nssz= svfw - mczw
# qrpw= nssz / dctm
# cwcp= qrpw + hglg
# vnqc= cwcp * glgp
# rrtz= tljt + vnqc
# nhbv= fmpq * rrtz
# wmsh= nhbv - ddhj
# rpmd= wmsh / bqvp
# wmff= gnph + rpmd
# jmhl= wmff + cfqf
# tqrr= gsmd + jmhl
# mfsc= tqrr / cjww
# mhzc= mfsc - mgmb
# rswz= mhzc * rfqf
# prng= rsqh + rswz
# qvhs= prng * gpvs
# lsgq= qvhs - mrnr
# hbvq= lsgq + hgsv
# fbvb= hbvq + ffmg
# qglg= vffz + fbvb
# vbfg= qglg / vdpc
# rqgl= vbfg + cgqj
# vvfw= rqgl * lwwl
# gjzt= vvfw - hdth
# lrhg= gjzt / jtln
# vjhc= lrhg - hzps
# pqtc= srtc * vjhc
# sbbm= pqtc + tcrd
# ncjl= sbbm / pmgv
# 	 23272443728885.0
# 	 3
# 		 69817331186655.0
# nvzf= humn - ptcw
# dbjg= nvzf + rhzd
# hprt= dbjg / hlzz
# thvp= mfqj + hprt
# ddjv= zcmw * thvp
# wvmh= ddjv - dbbn
# rtbj= fmwm * wvmh
# qqsq= mngg + rtbj
# svfw= qqsq / cfwb
# nssz= svfw - mczw
# qrpw= nssz / dctm
# cwcp= qrpw + hglg
# vnqc= cwcp * glgp
# rrtz= tljt + vnqc
# nhbv= fmpq * rrtz
# wmsh= nhbv - ddhj
# rpmd= wmsh / bqvp
# wmff= gnph + rpmd
# jmhl= wmff + cfqf
# tqrr= gsmd + jmhl
# mfsc= tqrr / cjww
# mhzc= mfsc - mgmb
# rswz= mhzc * rfqf
# prng= rsqh + rswz
# qvhs= prng * gpvs
# lsgq= qvhs - mrnr
# hbvq= lsgq + hgsv
# fbvb= hbvq + ffmg
# qglg= vffz + fbvb
# vbfg= qglg / vdpc
# rqgl= vbfg + cgqj
# vvfw= rqgl * lwwl
# gjzt= vvfw - hdth
# lrhg= gjzt / jtln
# vjhc= lrhg - hzps
# pqtc= srtc * vjhc
# sbbm= pqtc + tcrd
# 	 69817331186655.0
# 	 885
# 		 69817331185770.0
# nvzf= humn - ptcw
# dbjg= nvzf + rhzd
# hprt= dbjg / hlzz
# thvp= mfqj + hprt
# ddjv= zcmw * thvp
# wvmh= ddjv - dbbn
# rtbj= fmwm * wvmh
# qqsq= mngg + rtbj
# svfw= qqsq / cfwb
# nssz= svfw - mczw
# qrpw= nssz / dctm
# cwcp= qrpw + hglg
# vnqc= cwcp * glgp
# rrtz= tljt + vnqc
# nhbv= fmpq * rrtz
# wmsh= nhbv - ddhj
# rpmd= wmsh / bqvp
# wmff= gnph + rpmd
# jmhl= wmff + cfqf
# tqrr= gsmd + jmhl
# mfsc= tqrr / cjww
# mhzc= mfsc - mgmb
# rswz= mhzc * rfqf
# prng= rsqh + rswz
# qvhs= prng * gpvs
# lsgq= qvhs - mrnr
# hbvq= lsgq + hgsv
# fbvb= hbvq + ffmg
# qglg= vffz + fbvb
# vbfg= qglg / vdpc
# rqgl= vbfg + cgqj
# vvfw= rqgl * lwwl
# gjzt= vvfw - hdth
# lrhg= gjzt / jtln
# vjhc= lrhg - hzps
# pqtc= srtc * vjhc
# 	 69817331185770.0
# 	 5
# 		 13963466237154.0
# nvzf= humn - ptcw
# dbjg= nvzf + rhzd
# hprt= dbjg / hlzz
# thvp= mfqj + hprt
# ddjv= zcmw * thvp
# wvmh= ddjv - dbbn
# rtbj= fmwm * wvmh
# qqsq= mngg + rtbj
# svfw= qqsq / cfwb
# nssz= svfw - mczw
# qrpw= nssz / dctm
# cwcp= qrpw + hglg
# vnqc= cwcp * glgp
# rrtz= tljt + vnqc
# nhbv= fmpq * rrtz
# wmsh= nhbv - ddhj
# rpmd= wmsh / bqvp
# wmff= gnph + rpmd
# jmhl= wmff + cfqf
# tqrr= gsmd + jmhl
# mfsc= tqrr / cjww
# mhzc= mfsc - mgmb
# rswz= mhzc * rfqf
# prng= rsqh + rswz
# qvhs= prng * gpvs
# lsgq= qvhs - mrnr
# hbvq= lsgq + hgsv
# fbvb= hbvq + ffmg
# qglg= vffz + fbvb
# vbfg= qglg / vdpc
# rqgl= vbfg + cgqj
# vvfw= rqgl * lwwl
# gjzt= vvfw - hdth
# lrhg= gjzt / jtln
# vjhc= lrhg - hzps
# 	 13963466237154.0
# 	 380
# 		 13963466237534.0
# nvzf= humn - ptcw
# dbjg= nvzf + rhzd
# hprt= dbjg / hlzz
# thvp= mfqj + hprt
# ddjv= zcmw * thvp
# wvmh= ddjv - dbbn
# rtbj= fmwm * wvmh
# qqsq= mngg + rtbj
# svfw= qqsq / cfwb
# nssz= svfw - mczw
# qrpw= nssz / dctm
# cwcp= qrpw + hglg
# vnqc= cwcp * glgp
# rrtz= tljt + vnqc
# nhbv= fmpq * rrtz
# wmsh= nhbv - ddhj
# rpmd= wmsh / bqvp
# wmff= gnph + rpmd
# jmhl= wmff + cfqf
# tqrr= gsmd + jmhl
# mfsc= tqrr / cjww
# mhzc= mfsc - mgmb
# rswz= mhzc * rfqf
# prng= rsqh + rswz
# qvhs= prng * gpvs
# lsgq= qvhs - mrnr
# hbvq= lsgq + hgsv
# fbvb= hbvq + ffmg
# qglg= vffz + fbvb
# vbfg= qglg / vdpc
# rqgl= vbfg + cgqj
# vvfw= rqgl * lwwl
# gjzt= vvfw - hdth
# lrhg= gjzt / jtln
# 	 13963466237534.0
# 	 5
# 		 69817331187670.0
# nvzf= humn - ptcw
# dbjg= nvzf + rhzd
# hprt= dbjg / hlzz
# thvp= mfqj + hprt
# ddjv= zcmw * thvp
# wvmh= ddjv - dbbn
# rtbj= fmwm * wvmh
# qqsq= mngg + rtbj
# svfw= qqsq / cfwb
# nssz= svfw - mczw
# qrpw= nssz / dctm
# cwcp= qrpw + hglg
# vnqc= cwcp * glgp
# rrtz= tljt + vnqc
# nhbv= fmpq * rrtz
# wmsh= nhbv - ddhj
# rpmd= wmsh / bqvp
# wmff= gnph + rpmd
# jmhl= wmff + cfqf
# tqrr= gsmd + jmhl
# mfsc= tqrr / cjww
# mhzc= mfsc - mgmb
# rswz= mhzc * rfqf
# prng= rsqh + rswz
# qvhs= prng * gpvs
# lsgq= qvhs - mrnr
# hbvq= lsgq + hgsv
# fbvb= hbvq + ffmg
# qglg= vffz + fbvb
# vbfg= qglg / vdpc
# rqgl= vbfg + cgqj
# vvfw= rqgl * lwwl
# gjzt= vvfw - hdth
# 	 69817331187670.0
# 	 378
# 		 69817331188048.0
# nvzf= humn - ptcw
# dbjg= nvzf + rhzd
# hprt= dbjg / hlzz
# thvp= mfqj + hprt
# ddjv= zcmw * thvp
# wvmh= ddjv - dbbn
# rtbj= fmwm * wvmh
# qqsq= mngg + rtbj
# svfw= qqsq / cfwb
# nssz= svfw - mczw
# qrpw= nssz / dctm
# cwcp= qrpw + hglg
# vnqc= cwcp * glgp
# rrtz= tljt + vnqc
# nhbv= fmpq * rrtz
# wmsh= nhbv - ddhj
# rpmd= wmsh / bqvp
# wmff= gnph + rpmd
# jmhl= wmff + cfqf
# tqrr= gsmd + jmhl
# mfsc= tqrr / cjww
# mhzc= mfsc - mgmb
# rswz= mhzc * rfqf
# prng= rsqh + rswz
# qvhs= prng * gpvs
# lsgq= qvhs - mrnr
# hbvq= lsgq + hgsv
# fbvb= hbvq + ffmg
# qglg= vffz + fbvb
# vbfg= qglg / vdpc
# rqgl= vbfg + cgqj
# vvfw= rqgl * lwwl
# 	 69817331188048.0
# 	 2
# 		 34908665594024.0
# nvzf= humn - ptcw
# dbjg= nvzf + rhzd
# hprt= dbjg / hlzz
# thvp= mfqj + hprt
# ddjv= zcmw * thvp
# wvmh= ddjv - dbbn
# rtbj= fmwm * wvmh
# qqsq= mngg + rtbj
# svfw= qqsq / cfwb
# nssz= svfw - mczw
# qrpw= nssz / dctm
# cwcp= qrpw + hglg
# vnqc= cwcp * glgp
# rrtz= tljt + vnqc
# nhbv= fmpq * rrtz
# wmsh= nhbv - ddhj
# rpmd= wmsh / bqvp
# wmff= gnph + rpmd
# jmhl= wmff + cfqf
# tqrr= gsmd + jmhl
# mfsc= tqrr / cjww
# mhzc= mfsc - mgmb
# rswz= mhzc * rfqf
# prng= rsqh + rswz
# qvhs= prng * gpvs
# lsgq= qvhs - mrnr
# hbvq= lsgq + hgsv
# fbvb= hbvq + ffmg
# qglg= vffz + fbvb
# vbfg= qglg / vdpc
# rqgl= vbfg + cgqj
# 	 34908665594024.0
# 	 213.0
# 		 34908665593811.0
# nvzf= humn - ptcw
# dbjg= nvzf + rhzd
# hprt= dbjg / hlzz
# thvp= mfqj + hprt
# ddjv= zcmw * thvp
# wvmh= ddjv - dbbn
# rtbj= fmwm * wvmh
# qqsq= mngg + rtbj
# svfw= qqsq / cfwb
# nssz= svfw - mczw
# qrpw= nssz / dctm
# cwcp= qrpw + hglg
# vnqc= cwcp * glgp
# rrtz= tljt + vnqc
# nhbv= fmpq * rrtz
# wmsh= nhbv - ddhj
# rpmd= wmsh / bqvp
# wmff= gnph + rpmd
# jmhl= wmff + cfqf
# tqrr= gsmd + jmhl
# mfsc= tqrr / cjww
# mhzc= mfsc - mgmb
# rswz= mhzc * rfqf
# prng= rsqh + rswz
# qvhs= prng * gpvs
# lsgq= qvhs - mrnr
# hbvq= lsgq + hgsv
# fbvb= hbvq + ffmg
# qglg= vffz + fbvb
# vbfg= qglg / vdpc
# 	 34908665593811.0
# 	 3
# 		 104725996781433.0
# nvzf= humn - ptcw
# dbjg= nvzf + rhzd
# hprt= dbjg / hlzz
# thvp= mfqj + hprt
# ddjv= zcmw * thvp
# wvmh= ddjv - dbbn
# rtbj= fmwm * wvmh
# qqsq= mngg + rtbj
# svfw= qqsq / cfwb
# nssz= svfw - mczw
# qrpw= nssz / dctm
# cwcp= qrpw + hglg
# vnqc= cwcp * glgp
# rrtz= tljt + vnqc
# nhbv= fmpq * rrtz
# wmsh= nhbv - ddhj
# rpmd= wmsh / bqvp
# wmff= gnph + rpmd
# jmhl= wmff + cfqf
# tqrr= gsmd + jmhl
# mfsc= tqrr / cjww
# mhzc= mfsc - mgmb
# rswz= mhzc * rfqf
# prng= rsqh + rswz
# qvhs= prng * gpvs
# lsgq= qvhs - mrnr
# hbvq= lsgq + hgsv
# fbvb= hbvq + ffmg
# qglg= vffz + fbvb
# 	 104725996781433.0
# 	 134.0
# 		 104725996781299.0
# nvzf= humn - ptcw
# dbjg= nvzf + rhzd
# hprt= dbjg / hlzz
# thvp= mfqj + hprt
# ddjv= zcmw * thvp
# wvmh= ddjv - dbbn
# rtbj= fmwm * wvmh
# qqsq= mngg + rtbj
# svfw= qqsq / cfwb
# nssz= svfw - mczw
# qrpw= nssz / dctm
# cwcp= qrpw + hglg
# vnqc= cwcp * glgp
# rrtz= tljt + vnqc
# nhbv= fmpq * rrtz
# wmsh= nhbv - ddhj
# rpmd= wmsh / bqvp
# wmff= gnph + rpmd
# jmhl= wmff + cfqf
# tqrr= gsmd + jmhl
# mfsc= tqrr / cjww
# mhzc= mfsc - mgmb
# rswz= mhzc * rfqf
# prng= rsqh + rswz
# qvhs= prng * gpvs
# lsgq= qvhs - mrnr
# hbvq= lsgq + hgsv
# fbvb= hbvq + ffmg
# 	 104725996781299.0
# 	 510
# 		 104725996780789.0
# nvzf= humn - ptcw
# dbjg= nvzf + rhzd
# hprt= dbjg / hlzz
# thvp= mfqj + hprt
# ddjv= zcmw * thvp
# wvmh= ddjv - dbbn
# rtbj= fmwm * wvmh
# qqsq= mngg + rtbj
# svfw= qqsq / cfwb
# nssz= svfw - mczw
# qrpw= nssz / dctm
# cwcp= qrpw + hglg
# vnqc= cwcp * glgp
# rrtz= tljt + vnqc
# nhbv= fmpq * rrtz
# wmsh= nhbv - ddhj
# rpmd= wmsh / bqvp
# wmff= gnph + rpmd
# jmhl= wmff + cfqf
# tqrr= gsmd + jmhl
# mfsc= tqrr / cjww
# mhzc= mfsc - mgmb
# rswz= mhzc * rfqf
# prng= rsqh + rswz
# qvhs= prng * gpvs
# lsgq= qvhs - mrnr
# hbvq= lsgq + hgsv
# 	 104725996780789.0
# 	 596
# 		 104725996780193.0
# nvzf= humn - ptcw
# dbjg= nvzf + rhzd
# hprt= dbjg / hlzz
# thvp= mfqj + hprt
# ddjv= zcmw * thvp
# wvmh= ddjv - dbbn
# rtbj= fmwm * wvmh
# qqsq= mngg + rtbj
# svfw= qqsq / cfwb
# nssz= svfw - mczw
# qrpw= nssz / dctm
# cwcp= qrpw + hglg
# vnqc= cwcp * glgp
# rrtz= tljt + vnqc
# nhbv= fmpq * rrtz
# wmsh= nhbv - ddhj
# rpmd= wmsh / bqvp
# wmff= gnph + rpmd
# jmhl= wmff + cfqf
# tqrr= gsmd + jmhl
# mfsc= tqrr / cjww
# mhzc= mfsc - mgmb
# rswz= mhzc * rfqf
# prng= rsqh + rswz
# qvhs= prng * gpvs
# lsgq= qvhs - mrnr
# 	 104725996780193.0
# 	 432
# 		 104725996780625.0
# nvzf= humn - ptcw
# dbjg= nvzf + rhzd
# hprt= dbjg / hlzz
# thvp= mfqj + hprt
# ddjv= zcmw * thvp
# wvmh= ddjv - dbbn
# rtbj= fmwm * wvmh
# qqsq= mngg + rtbj
# svfw= qqsq / cfwb
# nssz= svfw - mczw
# qrpw= nssz / dctm
# cwcp= qrpw + hglg
# vnqc= cwcp * glgp
# rrtz= tljt + vnqc
# nhbv= fmpq * rrtz
# wmsh= nhbv - ddhj
# rpmd= wmsh / bqvp
# wmff= gnph + rpmd
# jmhl= wmff + cfqf
# tqrr= gsmd + jmhl
# mfsc= tqrr / cjww
# mhzc= mfsc - mgmb
# rswz= mhzc * rfqf
# prng= rsqh + rswz
# qvhs= prng * gpvs
# 	 104725996780625.0
# 	 5
# 		 20945199356125.0
# nvzf= humn - ptcw
# dbjg= nvzf + rhzd
# hprt= dbjg / hlzz
# thvp= mfqj + hprt
# ddjv= zcmw * thvp
# wvmh= ddjv - dbbn
# rtbj= fmwm * wvmh
# qqsq= mngg + rtbj
# svfw= qqsq / cfwb
# nssz= svfw - mczw
# qrpw= nssz / dctm
# cwcp= qrpw + hglg
# vnqc= cwcp * glgp
# rrtz= tljt + vnqc
# nhbv= fmpq * rrtz
# wmsh= nhbv - ddhj
# rpmd= wmsh / bqvp
# wmff= gnph + rpmd
# jmhl= wmff + cfqf
# tqrr= gsmd + jmhl
# mfsc= tqrr / cjww
# mhzc= mfsc - mgmb
# rswz= mhzc * rfqf
# prng= rsqh + rswz
# 	 20945199356125.0
# 	 541.0
# 		 20945199355584.0
# nvzf= humn - ptcw
# dbjg= nvzf + rhzd
# hprt= dbjg / hlzz
# thvp= mfqj + hprt
# ddjv= zcmw * thvp
# wvmh= ddjv - dbbn
# rtbj= fmwm * wvmh
# qqsq= mngg + rtbj
# svfw= qqsq / cfwb
# nssz= svfw - mczw
# qrpw= nssz / dctm
# cwcp= qrpw + hglg
# vnqc= cwcp * glgp
# rrtz= tljt + vnqc
# nhbv= fmpq * rrtz
# wmsh= nhbv - ddhj
# rpmd= wmsh / bqvp
# wmff= gnph + rpmd
# jmhl= wmff + cfqf
# tqrr= gsmd + jmhl
# mfsc= tqrr / cjww
# mhzc= mfsc - mgmb
# rswz= mhzc * rfqf
# 	 20945199355584.0
# 	 2
# 		 10472599677792.0
# nvzf= humn - ptcw
# dbjg= nvzf + rhzd
# hprt= dbjg / hlzz
# thvp= mfqj + hprt
# ddjv= zcmw * thvp
# wvmh= ddjv - dbbn
# rtbj= fmwm * wvmh
# qqsq= mngg + rtbj
# svfw= qqsq / cfwb
# nssz= svfw - mczw
# qrpw= nssz / dctm
# cwcp= qrpw + hglg
# vnqc= cwcp * glgp
# rrtz= tljt + vnqc
# nhbv= fmpq * rrtz
# wmsh= nhbv - ddhj
# rpmd= wmsh / bqvp
# wmff= gnph + rpmd
# jmhl= wmff + cfqf
# tqrr= gsmd + jmhl
# mfsc= tqrr / cjww
# mhzc= mfsc - mgmb
# 	 10472599677792.0
# 	 523
# 		 10472599678315.0
# nvzf= humn - ptcw
# dbjg= nvzf + rhzd
# hprt= dbjg / hlzz
# thvp= mfqj + hprt
# ddjv= zcmw * thvp
# wvmh= ddjv - dbbn
# rtbj= fmwm * wvmh
# qqsq= mngg + rtbj
# svfw= qqsq / cfwb
# nssz= svfw - mczw
# qrpw= nssz / dctm
# cwcp= qrpw + hglg
# vnqc= cwcp * glgp
# rrtz= tljt + vnqc
# nhbv= fmpq * rrtz
# wmsh= nhbv - ddhj
# rpmd= wmsh / bqvp
# wmff= gnph + rpmd
# jmhl= wmff + cfqf
# tqrr= gsmd + jmhl
# mfsc= tqrr / cjww
# 	 10472599678315.0
# 	 2
# 		 20945199356630.0
# nvzf= humn - ptcw
# dbjg= nvzf + rhzd
# hprt= dbjg / hlzz
# thvp= mfqj + hprt
# ddjv= zcmw * thvp
# wvmh= ddjv - dbbn
# rtbj= fmwm * wvmh
# qqsq= mngg + rtbj
# svfw= qqsq / cfwb
# nssz= svfw - mczw
# qrpw= nssz / dctm
# cwcp= qrpw + hglg
# vnqc= cwcp * glgp
# rrtz= tljt + vnqc
# nhbv= fmpq * rrtz
# wmsh= nhbv - ddhj
# rpmd= wmsh / bqvp
# wmff= gnph + rpmd
# jmhl= wmff + cfqf
# tqrr= gsmd + jmhl
# 	 20945199356630.0
# 	 253
# 		 20945199356377.0
# nvzf= humn - ptcw
# dbjg= nvzf + rhzd
# hprt= dbjg / hlzz
# thvp= mfqj + hprt
# ddjv= zcmw * thvp
# wvmh= ddjv - dbbn
# rtbj= fmwm * wvmh
# qqsq= mngg + rtbj
# svfw= qqsq / cfwb
# nssz= svfw - mczw
# qrpw= nssz / dctm
# cwcp= qrpw + hglg
# vnqc= cwcp * glgp
# rrtz= tljt + vnqc
# nhbv= fmpq * rrtz
# wmsh= nhbv - ddhj
# rpmd= wmsh / bqvp
# wmff= gnph + rpmd
# jmhl= wmff + cfqf
# 	 20945199356377.0
# 	 288
# 		 20945199356089.0
# nvzf= humn - ptcw
# dbjg= nvzf + rhzd
# hprt= dbjg / hlzz
# thvp= mfqj + hprt
# ddjv= zcmw * thvp
# wvmh= ddjv - dbbn
# rtbj= fmwm * wvmh
# qqsq= mngg + rtbj
# svfw= qqsq / cfwb
# nssz= svfw - mczw
# qrpw= nssz / dctm
# cwcp= qrpw + hglg
# vnqc= cwcp * glgp
# rrtz= tljt + vnqc
# nhbv= fmpq * rrtz
# wmsh= nhbv - ddhj
# rpmd= wmsh / bqvp
# wmff= gnph + rpmd
# 	 20945199356089.0
# 	 590
# 		 20945199355499.0
# nvzf= humn - ptcw
# dbjg= nvzf + rhzd
# hprt= dbjg / hlzz
# thvp= mfqj + hprt
# ddjv= zcmw * thvp
# wvmh= ddjv - dbbn
# rtbj= fmwm * wvmh
# qqsq= mngg + rtbj
# svfw= qqsq / cfwb
# nssz= svfw - mczw
# qrpw= nssz / dctm
# cwcp= qrpw + hglg
# vnqc= cwcp * glgp
# rrtz= tljt + vnqc
# nhbv= fmpq * rrtz
# wmsh= nhbv - ddhj
# rpmd= wmsh / bqvp
# 	 20945199355499.0
# 	 5
# 		 104725996777495.0
# nvzf= humn - ptcw
# dbjg= nvzf + rhzd
# hprt= dbjg / hlzz
# thvp= mfqj + hprt
# ddjv= zcmw * thvp
# wvmh= ddjv - dbbn
# rtbj= fmwm * wvmh
# qqsq= mngg + rtbj
# svfw= qqsq / cfwb
# nssz= svfw - mczw
# qrpw= nssz / dctm
# cwcp= qrpw + hglg
# vnqc= cwcp * glgp
# rrtz= tljt + vnqc
# nhbv= fmpq * rrtz
# wmsh= nhbv - ddhj
# 	 104725996777495.0
# 	 265.0
# 		 104725996777760.0
# nvzf= humn - ptcw
# dbjg= nvzf + rhzd
# hprt= dbjg / hlzz
# thvp= mfqj + hprt
# ddjv= zcmw * thvp
# wvmh= ddjv - dbbn
# rtbj= fmwm * wvmh
# qqsq= mngg + rtbj
# svfw= qqsq / cfwb
# nssz= svfw - mczw
# qrpw= nssz / dctm
# cwcp= qrpw + hglg
# vnqc= cwcp * glgp
# rrtz= tljt + vnqc
# nhbv= fmpq * rrtz
# 	 104725996777760.0
# 	 2
# 		 52362998388880.0
# nvzf= humn - ptcw
# dbjg= nvzf + rhzd
# hprt= dbjg / hlzz
# thvp= mfqj + hprt
# ddjv= zcmw * thvp
# wvmh= ddjv - dbbn
# rtbj= fmwm * wvmh
# qqsq= mngg + rtbj
# svfw= qqsq / cfwb
# nssz= svfw - mczw
# qrpw= nssz / dctm
# cwcp= qrpw + hglg
# vnqc= cwcp * glgp
# rrtz= tljt + vnqc
# 	 52362998388880.0
# 	 720
# 		 52362998388160.0
# nvzf= humn - ptcw
# dbjg= nvzf + rhzd
# hprt= dbjg / hlzz
# thvp= mfqj + hprt
# ddjv= zcmw * thvp
# wvmh= ddjv - dbbn
# rtbj= fmwm * wvmh
# qqsq= mngg + rtbj
# svfw= qqsq / cfwb
# nssz= svfw - mczw
# qrpw= nssz / dctm
# cwcp= qrpw + hglg
# vnqc= cwcp * glgp
# 	 52362998388160.0
# 	 2
# 		 26181499194080.0
# nvzf= humn - ptcw
# dbjg= nvzf + rhzd
# hprt= dbjg / hlzz
# thvp= mfqj + hprt
# ddjv= zcmw * thvp
# wvmh= ddjv - dbbn
# rtbj= fmwm * wvmh
# qqsq= mngg + rtbj
# svfw= qqsq / cfwb
# nssz= svfw - mczw
# qrpw= nssz / dctm
# cwcp= qrpw + hglg
# 	 26181499194080.0
# 	 607.0
# 		 26181499193473.0
# nvzf= humn - ptcw
# dbjg= nvzf + rhzd
# hprt= dbjg / hlzz
# thvp= mfqj + hprt
# ddjv= zcmw * thvp
# wvmh= ddjv - dbbn
# rtbj= fmwm * wvmh
# qqsq= mngg + rtbj
# svfw= qqsq / cfwb
# nssz= svfw - mczw
# qrpw= nssz / dctm
# 	 26181499193473.0
# 	 3
# 		 78544497580419.0
# nvzf= humn - ptcw
# dbjg= nvzf + rhzd
# hprt= dbjg / hlzz
# thvp= mfqj + hprt
# ddjv= zcmw * thvp
# wvmh= ddjv - dbbn
# rtbj= fmwm * wvmh
# qqsq= mngg + rtbj
# svfw= qqsq / cfwb
# nssz= svfw - mczw
# 	 78544497580419.0
# 	 584
# 		 78544497581003.0
# nvzf= humn - ptcw
# dbjg= nvzf + rhzd
# hprt= dbjg / hlzz
# thvp= mfqj + hprt
# ddjv= zcmw * thvp
# wvmh= ddjv - dbbn
# rtbj= fmwm * wvmh
# qqsq= mngg + rtbj
# svfw= qqsq / cfwb
# 	 78544497581003.0
# 	 3
# 		 235633492743009.0
# nvzf= humn - ptcw
# dbjg= nvzf + rhzd
# hprt= dbjg / hlzz
# thvp= mfqj + hprt
# ddjv= zcmw * thvp
# wvmh= ddjv - dbbn
# rtbj= fmwm * wvmh
# qqsq= mngg + rtbj
# 	 235633492743009.0
# 	 511.0
# 		 235633492742498.0
# nvzf= humn - ptcw
# dbjg= nvzf + rhzd
# hprt= dbjg / hlzz
# thvp= mfqj + hprt
# ddjv= zcmw * thvp
# wvmh= ddjv - dbbn
# rtbj= fmwm * wvmh
# 	 235633492742498.0
# 	 2
# 		 117816746371249.0
# nvzf= humn - ptcw
# dbjg= nvzf + rhzd
# hprt= dbjg / hlzz
# thvp= mfqj + hprt
# ddjv= zcmw * thvp
# wvmh= ddjv - dbbn
# 	 117816746371249.0
# 	 5
# 		 117816746371254.0
# nvzf= humn - ptcw
# dbjg= nvzf + rhzd
# hprt= dbjg / hlzz
# thvp= mfqj + hprt
# ddjv= zcmw * thvp
# 	 117816746371254.0
# 	 63
# 		 1870107085258.0
# nvzf= humn - ptcw
# dbjg= nvzf + rhzd
# hprt= dbjg / hlzz
# thvp= mfqj + hprt
# 	 1870107085258.0
# 	 119
# 		 1870107085139.0
# nvzf= humn - ptcw
# dbjg= nvzf + rhzd
# hprt= dbjg / hlzz
# 	 1870107085139.0
# 	 2
# 		 3740214170278.0
# nvzf= humn - ptcw
# dbjg= nvzf + rhzd
# 	 3740214170278.0
# 	 885.0
# 		 3740214169393.0
# nvzf= humn - ptcw
# 	 3740214169393.0
# 	 568
# 		 3740214169961.0

# %%
humn
# Out:
# 3740214169961.0

# %%
# 301 : too low

# %%
# Out:
# 	 21336560834689.56

# %%
print("\t"m
# Out:
# ['pqnb', 'twcj', 'jrfv']
