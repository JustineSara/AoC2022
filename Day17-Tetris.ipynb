# %% [raw]
# class rock :
#
#     def __init__(self,rtype) :
#
#         self.rtype = rtype
#
#         if rtype == 0 :
#             # h line
#             # P###   P =position
#
#             self.start_P = (+4,2)
#
#
#     def lat_move_0(self )

# %%
import numpy as np

# %%
test_input = """>>><<><>><<<>><>>><<<>>><<<><<<>><>><<>>"""

# %%
import requests

URL = "https://adventofcode.com/{year}/day/{day}/input"
url = URL.format(year='2022', day=17)
cookies = {"session":"53616c7465645f5fd345d8c12076a357c8d31b2c0c4ad1c152eefbd5c1cf09e0c8d6d7f657fc558887d443d2d07fbc90728ada9b6a91afcecb9926ffb4981a93"}
req = requests.get(url, cookies=cookies)

if req.status_code != 200:
    print("Error. Got status:", req.status_code)
    print(req.text)
    exit(3)
else:
    my_input = req.text

# %%
class tetris :
    
    def __init__(self,this_input) :
        
        self.rocks = [
            self.rock0(),
            self.rock1(),
            self.rock2(),
            self.rock3(),
            self.rock4()]
        self.space = np.ones((7,1))*10
        self.height = -1
        self.moves = this_input.split("\n")[0]
        
    def rock0(self) :
        r0 = np.zeros((7,4))
        r0[2:6,3]=1
        return r0
    def rock1(self):
        r1 = np.zeros((7,6))
        r1[2:5,4]=1
        r1[3,3:6]=1
        return r1
    def rock2(self):
        r2 = np.zeros((7,6))
        r2[2:5,3]=1
        r2[4,3:6]=1
        return r2
    def rock3(self):
        r3 = np.zeros((7,7))
        r3[2,3:7]=1
        return r3
    def rock4(self):
        r4 = np.zeros((7,5))
        r4[2:4,3:5]=1
        return r4

    def print_rock(self) :
        for i in range(len(self.rocks)) : 
            print("rock",i)
            s = ""
            for il in range(self.rocks[i].shape[1]-1,-1,-1) :
                l = self.rocks[i][:,il]
                for el in l :
                    if el == 1:
                        s+="#"
                    else :
                        s+="."
                s+="\n"
            s+="\n"
            print(s)
            
    def __str__(self) :
        s = ""
        for il in range(self.space.shape[1]-1,-1,-1) :
            l = self.space[:,il]
            for el in l :
                if el == 10:
                    s+="#"
                elif el == 1 :
                    s+="@"
                else :
                    s+="."
            s+="\n"
        return s
    
    def new_rock(self,i):
        self.space = np.c_[self.space,self.rocks[i]]
        
    def move_down(self):
        lx,ly = np.where(self.space==1)
        for x, y in zip(lx,ly) :
            self.space[x,y] = 0 
        
        if len(lx) == 0 :
#             print("nothing to move down")
            return False
        
        for x, y in zip(lx,ly) :
            if self.space[x,y-1] == 10 :
#                 print("touch down")
                for xm, ym in zip(lx,ly) :
                    self.space[xm,ym] = 10
                return False
        for x, y in zip(lx,ly) :
            self.space[x,y-1] = 1
        return True
        
    def move_lat_right(self) :
        lx,ly = np.where(self.space==1)
        
        for x, y in zip(lx,ly) :
            if x+1 >= self.space.shape[0] :
#                 print("moves out : nope")
                return False
            elif self.space[x+1,y] == 10 :
#                 print("obstacle")
                return False        
        
        for x, y in zip(lx,ly) :
            self.space[x,y] = 0 
        for x, y in zip(lx,ly) :
            self.space[x+1,y] = 1
        return True
        
    def move_lat_left(self) :
        lx,ly = np.where(self.space==1)
        
        for x, y in zip(lx,ly) :
            if x-1 <0 :
#                 print("moves out : nope")
                return False
            elif self.space[x-1,y] == 10 :
#                 print("obstacle")
                return False        
        
        for x, y in zip(lx,ly) :
            self.space[x,y] = 0 
        for x, y in zip(lx,ly) :
            self.space[x-1,y] = 1
        return True
        
        
    def get_YMIN(self) :
        yslist = list(np.where(self.space[0,:]==10)[0])
        yslist.reverse()
        
        LENX,LENY = self.space.shape
        
        for ystart in yslist :
            path = [ystart]
            ymin = [ystart]
            for x in range(1,7) :
                npath = []
                nymin = []
                for y,ym in zip(path,ymin) :
                    yyp = y+1
                    yym = y-1
                    if self.space[x,y] == 10 :
                        npath.append(y)
                        nymin.append(ym)
                    while yyp < LENY and self.space[x,yyp] == 10 : 
                        npath.append(yyp)
                        nymin.append(ym)
                        yyp += 1
                    while yym >= 0 and self.space[x,yym] == 10 :
                        npath.append(yym)
                        nymin.append(min(ym,yym))
                        yym-=1
                path = npath
                ymin = nymin

            if len(path) > 0:
                self.height += max(ymin)
                return max(ymin)

    def get_YMIN_C(self):
        
        yslist = list(np.where(self.space[0,:]==10)[0])
        yslist.reverse()
        
        LENX,LENY = self.space.shape
        
        for ystart in yslist :
            if ystart == 0 :
                return 0
            path = [(0,ystart)]
            ymin = [ystart]
            while i in range(20) :
                npath = []
                nymin = []
                for pos,ym in zip(path,ymin) :
                    x,y = pos
                    if self.space[x+1,y] == 10 :
                        if x+1 == self.space.shape[0] -1  :
                            self.height += ym
                            return ym
                        if (x+1,y) not in npath :
                            npath.append((x+1,y))
                            nymin.append(ym)
                    if y+1 < LENY and t.space[x,y+1] == 10 and (x,y+1) not in npath :
                            npath.append((x,y+1))
                            nymin.append(ym)
                    if y-1>=0 and self.space[x,y-1] == 10 and (x,y-1) not in npath :
                            npath.append((x,y-1))
                            nymin.append(min(ym,y-1))
                    if y+1<LENY and self.space[x+1,y+1] == 10 :
                        if x+1 == LENX -1  :
                            return ym
                        if (x+1,y+1) not in npath :
                            npath.append((x+1,y+1))
                            nymin.append(ym)
                    if y-1>=0 and self.space[x+1,y-1] == 10 :
                        ym = min(ym,y-1)
                        if x+1 == LENX -1  :
                            self.height += ym
                            return ym
                        if (x+1,y-1) not in npath :
                            npath.append((x+1,y-1))
                            nymin.append(ym)


                path = npath
                ymin = nymin
                
        return 0
    
    
    def trim_space(self):
        YMIN = self.get_YMIN()
#         YMIN = 0
        YMAX = np.where(t.space.sum(0)>0)[0][-1]+1
        self.space = self.space[:,YMIN:YMAX]
        
    def get_max_height(self):
        self.trim_space()
        return self.height + self.space.shape[1]
    
    def part1(self,Nrocks) :
        
        ir = 0
        ilm = 0
        
        for i in range(Nrocks) :
            
            if i % 1000 == 0 :
                print(i,self.get_max_height())
            
            # generate a rock
            self.new_rock(ir)
            ir += 1
            if ir == len(self.rocks) :
                ir = 0
            
            # move the rock
            canmove = True
            while canmove :
                if self.moves[ilm] == ">" :
                    self.move_lat_right()
                elif self.moves[ilm] == "<" :
                    self.move_lat_left()
                else :
                    print("pbm : invalid move input : ",self.moves[ilm])
#                 print(self.moves[ilm])
                ilm += 1
                if ilm == len(self.moves) :
                    ilm = 0
                
                canmove = self.move_down()
                
            # trim the space
            self.trim_space()
            
        return True
#         return self.get_max_height()

# %%
test_input
# Out:
# '>>><<><>><<<>><>>><<<>>><<<><<<>><>><<>>'

# %%
t = tetris(test_input)

# %%
t = tetris(test_input)
t.part1(2022)
# Out:
# True

# %% [raw]
# 20 rocks :
# with no bottom triming => 37-1 = 36 (probably right)
# with bottom triming => 19 36 too but might have a problem

# %%
t.space.shape[1] + t.height
# Out:
# 4

# %%
t.get_max_height()
# Out:
# 3068

# %%
print(t)
# Out:
# ....#..
# ....#..
# ....#..
# ....#..
# .##.#..
# .##.#..
# ..###..
# ...#...
# ..###..
# ...#...
# ..####.
# .....##
# .....##
# ......#
# ......#
# ...####
# ..###..
# ...#...
# #..####
# #...#..
# #...#..
# #...##.
# ##..##.
# ######.

# %%
yslist = list(np.where(t.space[0,:]==10)[0])
yslist.reverse()
yslist
# Out:
# [18, 17, 16, 15, 14, 13, 4, 0]

# %%
ystart = 18
LENX,LENY = t.space.shape
path = [(0,ystart)]
ymin = [ystart]
while len(path) > 0 :
    npath = []
    nymin = []
    for pos,ym in zip(path,ymin) :
        x,y = pos
#         print(x,y,ym)
#         print(t.space[x,y])
        if t.space[x+1,y] == 10 :
            if x+1 == t.space.shape[0] -1  :
                print("\t",ym)
                npath = []
                break
            if (x+1,y) not in npath :
                npath.append((x+1,y))
                nymin.append(ym)
        if y+1 < LENY and t.space[x,y+1] == 10 :
            if (x,y+1) not in npath :
                npath.append((x,y+1))
                nymin.append(ym)
        if y-1>=0 and t.space[x,y-1] == 10 :
            if (x,y-1) not in npath :
                npath.append((x,y-1))
                nymin.append(min(ym,y-1))
        if y+1<t.space.shape[1] and t.space[x+1,y+1] == 10 :
            if x+1 == LENX -1  :
                print("\t",ym)
                npath = []
                break
            if (x+1,y+1) not in npath :
                npath.append((x+1,y+1))
                nymin.append(ym)
        if y-1>=0 and t.space[x+1,y-1] == 10 :
            ym = min(ym,y-1)
            if x+1 == LENX -1  :
                print("\t",ym)
                npath = []
                break
            if (x+1,y-1) not in npath :
                npath.append((x+1,y-1))
                nymin.append(ym)
        
            
    path = npath
    ymin = nymin
    print(path)
# Out:
# [(0, 17)]
# [(0, 18), (0, 16)]
# [(0, 17), (0, 15)]
# [(0, 18), (0, 16), (0, 14), (1, 14)]
# [(0, 17), (0, 15), (1, 14), (0, 13), (1, 13), (2, 13)]
# [(0, 18), (0, 16), (0, 14), (1, 14), (1, 13), (2, 13), (1, 12), (2, 12), (3, 13), (3, 12)]
# [(0, 17), (0, 15), (1, 14), (0, 13), (1, 13), (2, 13), (1, 12), (2, 12), (3, 13), (3, 12), (2, 11), (4, 13), (4, 14)]
# [(0, 18), (0, 16), (0, 14), (1, 14), (1, 13), (2, 13), (1, 12), (2, 12), (3, 13), (3, 12), (2, 11), (4, 13), (4, 14), (2, 10), (3, 10), (5, 13), (5, 14), (4, 15), (5, 15)]
# [(0, 17), (0, 15), (1, 14), (0, 13), (1, 13), (2, 13), (1, 12), (2, 12), (3, 13), (3, 12), (2, 11), (4, 13), (4, 14), (2, 10), (3, 10), (5, 13), (5, 14), (4, 15), (5, 15), (4, 10), (4, 9), (4, 16)]
# [(0, 18), (0, 16), (0, 14), (1, 14), (1, 13), (2, 13), (1, 12), (2, 12), (3, 13), (3, 12), (2, 11), (4, 13), (4, 14), (2, 10), (3, 10), (5, 13), (5, 14), (4, 15), (5, 15), (4, 10), (4, 9), (4, 16), (5, 9), (4, 8), (5, 8), (4, 17)]
# [(0, 17), (0, 15), (1, 14), (0, 13), (1, 13), (2, 13), (1, 12), (2, 12), (3, 13), (3, 12), (2, 11), (4, 13), (4, 14), (2, 10), (3, 10), (5, 13), (5, 14), (4, 15), (5, 15), (4, 10), (4, 9), (4, 16), (5, 9), (4, 8), (5, 8), (4, 17), (4, 7), (4, 18), (5, 18)]
# 	 13
# []

# %%
print(t)
# Out:
# ....#..
# ....#..
# ....#..
# ....#..
# .##.#..
# .##.#..
# ..###..
# ...#...
# ..###..
# ...#...
# ..####.
# .....##
# .....##
# ......#
# ......#
# ...####
# ..###..
# ...#...
# #..####
# #...#..
# #...#..
# #...##.
# ##..##.
# ######.
# .###...
# ..#....
# .####..
# ....##.
# ....##.
# ....#..
# ..#.#..
# ..#.#..
# #####..
# ..###..
# ...#...
# ..####.
# #######

# %%
t = tetris(test_input)
t.part1(2022)
# Out:
# True

# %%
print(t)
# Out:
# ...#...
# ..###..
# ...#...
# ..####.
# .##....
# .##...#
# ..#...#
# ..#.###
# ..#..#.
# ..#.###
# .#####.
# ....#..
# ....#..
# ....#..
# ....#..
# .##.#..
# .##.#..
# ..###..
# ...#...
# ..###..
# ...#...
# ..####.
# ..###..
# ..###..
# ..####.
# ....###
# .....#.
# .#####.
# .#..#..
# .#..#..
# .####.#
# .####.#
# ###.###
# .#####.
# .###...
# .###...
# .#.#...
# .#.#.#.
# .######
# .#####.
# ....#..
# ....#..
# ....#..
# ....#..
# .##.#..
# .##.#..
# ..###..
# ....#..
# ...###.

# %%
t = tetris(my_input)

# %%
t.part1(2022)
# 3237 : too high
# 3197 : right answer
# Out:
# True

# %%
t.get_max_height()
# Out:
# 3197

# %%
print(t)
# Out:
# ...#...
# ..###..
# ...#...
# .####..
# ..##..#
# ..##..#
# ...####
# ..###..
# ...#...
# ..####.
# ..##...
# ..##...
# ..#....
# ..#...#
# #.#...#
# #.#####
# #.###..
# #..#...
# ####...

# %%
t.space

# %%
for ylim in range(t.space.shape[1]):
    for x in range(t.space.shape[0]):
        if t.space[x,ylim:].sum() == 0 :
            print(ylim-1)
# Out:
# 29
# 29
# 30
# 30
# 30
# 31
# 31
# 31
# 32
# 32
# 32
# 33
# 33
# 33
# 34
# 34
# 34

# %%
yslist = list(np.where(t.space[0,:]==10)[0])
yslist.reverse()
for ystart in yslist : 
    print(ystart)
    path = [ystart]
    ymin = [ystart]
# 163
# 161
# 156
# 	 155
# 155
# 	 155
# 145
# 137
# 135
# 116
# 115
# 114
# 113
# 	 109
# 112
# 	 109
# 100
# 89
# 88
# 86
# 61
# 	 59
# 54
# 	 54
# 49
# 48
# 47
# 36
# 	 34
# 29
# 	 29
# 20
# 	 20
# 4
# 3
# 	 2
# 2
# 	 2
# 1
# 	 1
# 0
# 	 0

# %%
ystart=3183

path = [ystart]
ymin = [ystart]
for x in range(1,7) :
    npath = []
    nymin = []
    for y,ym in zip(path,ymin) :
        if t.space[x,y] == 10 :
            npath.append(y)
            nymin.append(ym)
        if y+1 < t.space.shape[1] and t.space[x,y+1] == 10 :
            npath.append(y+1)
            nymin.append(ym)
        if y-1>=0 and t.space[x,y-1] == 10 :
            npath.append(y-1)
            nymin.append(min(ym,y-1))
    path = npath
    ymin = nymin

if len(path) > 0:
    print(max(ymin))

# %%
t = tetris(test_input)
t.part1(1000000000000)
# Out:
# 0 0
# 1000 1520
# 2000 3034
# 3000 4548
# 4000 6061
# 5000 7577
# 6000 9088
# 7000 10607
# 8000 12120
# 9000 13634
# 10000 15148
# 11000 16661
# 12000 18177
# 13000 19688
# 14000 21207
# 15000 22720
# 16000 24234
# 17000 25748
# 18000 27261
# 19000 28777
# 20000 30288
# 21000 31807
# 22000 33320
# 23000 34834
# 24000 36348
# 25000 37861
# 26000 39377
# 27000 40888
# 28000 42407
# 29000 43920
# 30000 45434
# 31000 46948
# 32000 48461
# 33000 49977
# 34000 51488
# 35000 53007
# 36000 54520
# 37000 56034
# 38000 57548
# 39000 59061
# 40000 60577
# 41000 62088
# 42000 63607
# 43000 65120
# 44000 66634
# 45000 68148
# 46000 69661
# 47000 71177
# 48000 72688
# 49000 74207
# 50000 75720
# 51000 77234
# 52000 78748
# 53000 80261
# 54000 81777
# 55000 83288
# 56000 84807
# 57000 86320
# 58000 87834
# 59000 89348
# 60000 90861
# 61000 92377
# 62000 93888
# 63000 95407
# 64000 96920
# 65000 98434
# 66000 99948
# 67000 101461
# 68000 102977
# 69000 104488
# 70000 106007
# 71000 107520
# 72000 109034
# 73000 110548
# 74000 112061
# 75000 113577
# 76000 115088
# 77000 116607
# 78000 118120
# 79000 119634
# 80000 121148
# 81000 122661
# 82000 124177
# 83000 125688
# 84000 127207
# 85000 128720
# 86000 130234
# 87000 131748
# 88000 133261
# 89000 134777
# 90000 136288
# 91000 137807
# 92000 139320
# 93000 140834
# 94000 142348
# 95000 143861
# 96000 145377
# 97000 146888
# 98000 148407
# 99000 149920
# 100000 151434
# 101000 152948
# 102000 154461
# 103000 155977
# 104000 157488
# 105000 159007
# 106000 160520
# 107000 162034
# 108000 163548
# 109000 165061
# 110000 166577
# 111000 168088
# 112000 169607
# 113000 171120
# 114000 172634
# 115000 174148
# 116000 175661
# 117000 177177
# 118000 178688
# 119000 180207
# 120000 181720
# 121000 183234
# 122000 184748
# 123000 186261
# 124000 187777
# 125000 189288
# 126000 190807
# 127000 192320
# 128000 193834
# 129000 195348
# 695000 1052434
# 696000 1053948
# 697000 1055461
# 698000 1056977
# 699000 1058488
# 700000 1060007
# 701000 1061520
# 702000 1063034
# 703000 1064548
# 704000 1066061
# 705000 1067577
# 706000 1069088
# 707000 1070607
# 708000 1072120
# 709000 1073634
# 710000 1075148
# 711000 1076661
# 712000 1078177
# 713000 1079688
# 714000 1081207
# 715000 1082720
# 716000 1084234
# 717000 1085748
# 718000 1087261
# 719000 1088777
# 720000 1090288
# 721000 1091807
# 722000 1093320
# 723000 1094834
# 724000 1096348
# 725000 1097861
# 726000 1099377
# 727000 1100888
# 728000 1102407
# 729000 1103920
# 730000 1105434
# 731000 1106948
# 732000 1108461
# 733000 1109977
# 734000 1111488
# 735000 1113007
# 736000 1114520
# 737000 1116034
# 738000 1117548
# 739000 1119061
# 740000 1120577
# 741000 1122088
# 742000 1123607
# 743000 1125120
# 744000 1126634
# 745000 1128148
# 746000 1129661
# 747000 1131177
# 748000 1132688
# 749000 1134207
# 750000 1135720
# 751000 1137234
# 752000 1138748
# 753000 1140261
# 754000 1141777
# 755000 1143288
# 756000 1144807
# 757000 1146320
# 758000 1147834
# 759000 1149348
# 760000 1150861
# 761000 1152377
# 762000 1153888
# 763000 1155407
# 764000 1156920
# 765000 1158434
# 766000 1159948
# 767000 1161461
# 768000 1162977
# 769000 1164488
# 770000 1166007
# 771000 1167520
# 772000 1169034
# 773000 1170548
# 774000 1172061
# 775000 1173577
# 776000 1175088
# 777000 1176607
# 778000 1178120
# 779000 1179634
# 780000 1181148
# 781000 1182661
# 782000 1184177
# 783000 1185688
# 784000 1187207
# 785000 1188720
# 786000 1190234
# 787000 1191748
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [444], in <module>
#       1 t = tetris(test_input)
# ----> 2 t.part1(1000000000000)
#
# Input In [443], in tetris.part1(self, Nrocks)
#     249         canmove = self.move_down()
#     251     # trim the space
# --> 252     self.trim_space()
#     254 return True
#
# Input In [443], in tetris.trim_space(self)
#     209     def trim_space(self):
# --> 210         YMIN = self.get_YMIN()
#     211 #         YMIN = 0
#     212         YMAX = np.where(t.space.sum(0)>0)[0][-1]+1
#
# Input In [443], in tetris.get_YMIN(self)
#     146     while yym >= 0 and self.space[x,yym] == 10 :
#     147         npath.append(yym)
# --> 148         nymin.append(min(ym,yym))
#     149         yym-=1
#     150 path = npath
#
# KeyboardInterrupt:

# %%
t.get_max_height() == 1514285714288

# %%
import time

# %%
class tetris2 :
    
    def __init__(self,this_input) :
        
        self.rocks = [
            self.rock0(),
            self.rock1(),
            self.rock2(),
            self.rock3(),
            self.rock4()]
        self.space = np.ones((7,1))*10
        self.height = -1
        self.moves = this_input.split("\n")[0]
        
    def rock0(self) :
        r0 = np.zeros((7,1))
        r0[2:6,0]=1
        return r0
    def rock1(self):
        r1 = np.zeros((7,3))
        r1[2:5,1]=1
        r1[3,0:3]=1
        return r1
    def rock2(self):
        r2 = np.zeros((7,3))
        r2[2:5,0]=1
        r2[4,0:3]=1
        return r2
    def rock3(self):
        r3 = np.zeros((7,4))
        r3[2,0:4]=1
        return r3
    def rock4(self):
        r4 = np.zeros((7,2))
        r4[2:4,0:2]=1
        return r4

    def print_rock(self) :
        for i in range(len(self.rocks)) : 
            print("rock",i)
            s = ""
            for il in range(self.rocks[i].shape[1]-1,-1,-1) :
                l = self.rocks[i][:,il]
                for el in l :
                    if el == 1:
                        s+="#"
                    else :
                        s+="."
                s+="\n"
            s+="\n"
            print(s)
            
    def __str__(self) :
        s = ""
        for il in range(self.space.shape[1]-1,-1,-1) :
            l = self.space[:,il]
            for el in l :
                if el == 10:
                    s+="#"
                elif el == 1 :
                    s+="@"
                else :
                    s+="."
            s+="\n"
        return s
    
    def new_rock(self,i):
        self.space = np.c_[self.space,self.rocks[i]]
        
    def move_down(self):
        lx,ly = np.where(self.space==1)
        for x, y in zip(lx,ly) :
            self.space[x,y] = 0 
        
        if len(lx) == 0 :
            return False
        
        for x, y in zip(lx,ly) :
            if self.space[x,y-1] == 10 :
                for xm, ym in zip(lx,ly) :
                    self.space[xm,ym] = 10
                return False
        for x, y in zip(lx,ly) :
            self.space[x,y-1] = 1
        return True
        
    def move_lat_right(self) :
        lx,ly = np.where(self.space==1)
        
        for x, y in zip(lx,ly) :
            if x+1 >= self.space.shape[0] :
                return False
            elif self.space[x+1,y] == 10 :
                return False        
        
        for x, y in zip(lx,ly) :
            self.space[x,y] = 0 
        for x, y in zip(lx,ly) :
            self.space[x+1,y] = 1
        return True
        
    def move_lat_left(self) :
        lx,ly = np.where(self.space==1)
        
        for x, y in zip(lx,ly) :
            if x-1 <0 :
                return False
            elif self.space[x-1,y] == 10 :
                return False        
        
        for x, y in zip(lx,ly) :
            self.space[x,y] = 0 
        for x, y in zip(lx,ly) :
            self.space[x-1,y] = 1
        return True
        
        
    def get_YMIN(self) :
        yslist = list(np.where(self.space[0,:]==10)[0])
        yslist.reverse()
        
        LENX,LENY = self.space.shape
        
        for ystart in yslist :
            path = [ystart]
            ymin = [ystart]
            for x in range(1,7) :
                npath = []
                nymin = []
                for y,ym in zip(path,ymin) :
                    yyp = y+1
                    yym = y-1
                    if self.space[x,y] == 10 :
                        npath.append(y)
                        nymin.append(ym)
                    while yyp < LENY and self.space[x,yyp] == 10 : 
                        npath.append(yyp)
                        nymin.append(ym)
                        yyp += 1
                    while yym >= 0 and self.space[x,yym] == 10 :
                        npath.append(yym)
                        nymin.append(min(ym,yym))
                        yym-=1
                path = npath
                ymin = nymin

            if len(path) > 0:
                self.height += max(ymin)
                return max(ymin)
         
    def get_YMIN_2(self) :
        yslist = list(np.where(self.space[0,:]==10)[0])
        yslist.reverse()
        
        LENX,LENY = self.space.shape
        
        for ystart in yslist :
            path = [ystart]
            ymin = [ystart]
            for x in range(1,7) :
                npath = []
                nymin = []
                for y,ym in zip(path,ymin) :
                    yyp = y+1
                    yym = y-1
                    if self.space[x,y] == 10 :
                        npath.append(y)
                        nymin.append(ym)
                    if yyp < LENY and self.space[x,yyp] == 10 : 
                        npath.append(yyp)
                        nymin.append(ym)
                    if yym >= 0 and self.space[x,yym] == 10 :
                        npath.append(yym)
                        nymin.append(min(ym,yym))
                        
                path = npath
                ymin = nymin

            if len(path) > 0:
                self.height += max(ymin)
                return max(ymin)
            
    def get_YMIN_3(self):
        
        LENX,LENY = self.space.shape
        if LENY < 500 :
            return 0
        ymin = 250
        self.height += ymin
        return ymin
            
    def get_YMAX(self) :
        y = self.space.shape[1]-1
        while sum(self.space[:,y]) == 0 :
            y -= 1
        return y+1
    
    def trim_space(self):
#         YMIN = self.get_YMIN()
#         YMIN = 0
#         YMIN = self.get_YMIN_2()
        YMIN = self.get_YMIN_3()
#         YMAX = np.where(self.space.sum(0)>0)[0][-1]+1
        YMAX = self.get_YMAX()
        self.space = self.space[:,YMIN:YMAX]
        
    def get_max_height(self):
        self.trim_space()
        return self.height + self.space.shape[1]
    
    def part2(self,Nrocks) :
        
        ir = 0
        ilm = 0
        st = time.perf_counter()

        for i in range(Nrocks) :
            if i % 10000 == 0 :
                print(i,self.get_max_height(),time.perf_counter()-st)
                st=time.perf_counter()
            
            # generate a rock
            self.new_rock(ir)
            ir += 1
            if ir == len(self.rocks) :
                ir = 0
            
            # 4 lateral moves first while it falls unimpeded
            for ii in range(4):
                if self.moves[ilm] == ">" :
                    self.move_lat_right()
                elif self.moves[ilm] == "<" :
                    self.move_lat_left()
                else :
                    print("pbm : invalid move input : ",self.moves[ilm])
                ilm += 1
                if ilm == len(self.moves) :
                    ilm = 0
            
            # move the rock
            while self.move_down() :
                if self.moves[ilm] == ">" :
                    self.move_lat_right()
                elif self.moves[ilm] == "<" :
                    self.move_lat_left()
                else :
                    print("pbm : invalid move input : ",self.moves[ilm])
                ilm += 1
                if ilm == len(self.moves) :
                    ilm = 0
                
            # trim the space
            self.trim_space()
            
        return self.get_max_height()

# %%
t = tetris2(test_input)
t.part2(50000)
# 75720
# Out:
# 0 0 2.8100039344280958e-05
# 10000 15148 5.498898100049701
# 20000 30288 5.496988600003533
# 30000 45434 5.547603400016669
# 40000 60577 5.5852071000263095
# 75720

# %%
t = tetris2(test_input)
r,addedh = t.part2(100000)
# 75720
# 157
# Out:
# 0 0 4.169996827840805e-05
# 10000 15148 5.702863299986348
# 20000 30288 5.851015300024301
# 30000 45434 5.893729400006123
# 40000 60577 5.6526598999626
# 50000 75720 5.876330700004473
# 60000 90861 5.803561600041576
# 70000 106007 6.05185829999391
# 80000 121148 5.667300800036173
# 90000 136288 5.7023440999910235

# %%
addedh*1000000000000
# Out:
# 1514340000000.0

# %%
r
# Out:
# 151434

# %%
class tetris3 :
    
    def __init__(self,this_input) :
        
        spaceOx = [0,1,2,3,4,5,6]
        spaceOy = [0,0,0,0,0,0,0]
#         self.spaceO = [(x,y) for x,y in zip(spaceOx,spaceOy)]
        self.spaceO = {0: [0,1,2,3,4,5,6]}
        self.moves = this_input.split("\n")[0]
        self.h = 0
 
    def rock(self,i) :
        h = self.h +1
        if i == 0 :
            rX = [2,3,4,5]
            rY = [h]*4
        elif i ==1 :
            rX = [2,3,3,3,4]
            rY = [h+1,h+1,h+2,h,h+1]
        elif i ==2 :
            rX = [2,3,4,4,4]
            rY = [h,h,h,h+1,h+2]
        elif i ==3 :
            rX = [2,2,2,2]
            rY = [h,h+1,h+2,h+3]
        elif i == 4 :
            rX = [2,3,2,3]
            rY = [h,h,h+1,h+1]
        return rX,rY
    
        
    def move_down(self,rX,rY):
        add_to_occupied = False
        for x,y in zip(rX,rY) :
            if y-1<=self.h and x in self.spaceO[y-1] :
                add_to_occupied = True
                break
        if add_to_occupied :
            for x,y in zip(rX,rY) :
                if y in self.spaceO.keys() :
                    self.spaceO[y].append(x)
                else :
                    self.spaceO[y] = [x]
            self.h = max(self.h,max(rY))
            return None, None
        return rX,[y-1 for y in rY]
        
    def move_lat_right(self,rX,rY) :
        if max(rX) == 6 :
            return rX,rY
        for x, y in zip(rX,rY) :
            if y <= self.h and x+1 in self.spaceO[y] :
                return rX,rY        
        return [x+1 for x in rX],rY
        
    def move_lat_left(self,rX,rY) :
        if min(rX) == 0 :
            return rX,rY
        for x, y in zip(rX,rY) :
            if y <= self.h and x-1 in self.spaceO[y] :
                return rX,rY        
        return [x-1 for x in rX],rY
        
    
    def trim_space(self):
        k = list(self.spaceO.keys())
        if max(k) - min(k) > 250 :
            for i in range(min(k),min(k)+50) :
                del self.spaceO[i]
        
    
    def part2(self,Nrocks) :
        
        ir = 0
        ilm = 0
        st = time.perf_counter()

        for i in range(Nrocks) :
            if i % 1000000 == 0 :
                print(i,self.h,time.perf_counter()-st)
                st=time.perf_counter()
            
            # generate a rock
            rX,rY = self.rock(ir)
            ir += 1
            if ir == 5 :
                ir = 0
            
            # 4 lateral moves first while it falls unimpeded
            for ii in range(4):
                if self.moves[ilm] == ">" :
                    rX,rY = self.move_lat_right(rX,rY)
                elif self.moves[ilm] == "<" :
                    rX,rY = self.move_lat_left(rX,rY)
                ilm += 1
                if ilm == len(self.moves) :
                    ilm = 0
            
            # move the rock
            while True :
                rX,rY = self.move_down(rX,rY)
                if rX is None :
                    break
                if self.moves[ilm] == ">" :
                    rX,rY=self.move_lat_right(rX,rY)
                elif self.moves[ilm] == "<" :
                    rX,rY=self.move_lat_left(rX,rY)
                ilm += 1
                if ilm == len(self.moves) :
                    ilm = 0
                
            # trim the space
            self.trim_space()
            
        return self.h

# %%
t = tetris3(test_input)
t.part2(2)
# 4
# Out:
# 0 0 4.200031980872154e-06
# 4

# %%
t = tetris3(test_input)
t.part2(10)
# 17
# Out:
# 0 0 4.00003045797348e-06
# 17

# %%
t = tetris3(test_input)
t.part2(50000)
# 75720
# Out:
# 0 0 2.800021320581436e-06
# 10000 15148 0.2731318000005558
# 20000 30288 0.4618692999938503
# 30000 45434 0.5164804999949411
# 40000 60577 0.4652293000253849
# 75720

# %%
t = tetris3(test_input)
t.part2(50000)
# 75720

# %%
t = tetris3(my_input)
t.part2(1000000000000)
# Out:
# 0 0 5.299982149153948e-06
# 1000000 1568530 36.62695339997299
# 2000000 3137054 37.347084899956826
